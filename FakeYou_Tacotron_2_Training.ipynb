# %% [markdown]
# # <b><font color="pink" size="+2"> **FakeYou Tacotron 2 Training Colab**
# ___
#
# #### Follow the steps, executing the cells in order, to use.
#
# ___
#
# Last update: 07/07/2023
#
# ### [Tacotron 2](https://github.com/NVIDIA/tacotron2)
# <a href="https://fakeyou.com/"><img src="https://fakeyou.com/fakeyou/FakeYou-Logo.png" alt="FakeYou Logo. Click here to go to the official website."></a>
#
# ---
#
# ### **Disclaimer:** You may encounter difficulties when uploading files (> 1MB) if you use firefox.
# ---
#
# ## 🤝**Credits**🤝
# Code originally created by `CookieGalaxy#8351` for the Pony Preservation Project
#
# Colab notebook prepared by `justinjohn-03`.
#
# Special thanks to `mega b#669696`, `oJoão#3244`, `Cris140#6815` and `RanmaAR`.

# %% [markdown]
# #📚 <font color="pink"> ***Preparation*** 📚

# %%
#@markdown # <font color="pink"> **Check the GPU** 👁️ </font>
#@markdown ---
#@markdown #### It is not recommended to use the <font color="orange">**K80**</font> card (although it works correctly, it is **time consuming**). Restart the runtime to **get another card**.

# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-75323e3c-b732-86a5-7635-412da39d837a)

# %% [markdown]
# # <font color="pink"> ***Training*** </font> 🤖

# %%
#@markdown ## <font color="pink"> **1. Mount your Google Drive.** 📂

#Google Drive Authentication Token
from google.colab import drive
drive.mount('drive', force_remount=True)
# Out:
# Mounted at drive

# %%
#@markdown ## <font color="pink"> **2. Install Tacotron2 (w/ARPAbet).**  📦
# %matplotlib inline
import os
import io
# %cd /content/
if not os.path.isdir("/content/TTS-TT2/"):
  print("Cloning justinjohn0306/TTS-TT2")
  # !git clone https://github.com/justinjohn0306/ARPAtaco2.git TTS-TT2
  # %cd /content/TTS-TT2/
  # !git submodule init
  # !git submodule update
# %cd /content/TTS-TT2/
#NVIDIA's requirements
#I believe Colab gives us PyTorch and TF by default so we don't need anything else
#Versions specified in requirements.txt have conflicts so that's why we simply get current versions
print("Downloading tacotron2 requirements")
# !pip install matplotlib numpy inflect scipy Unidecode pillow
#Our requirements
#We'll need gdown to download some really cool things
# !pip install git+https://github.com/wkentaro/gdown.git
import gdown
# !git submodule init
# !git submodule update
# !pip install ffmpeg-normalize
# !pip install -q unidecode tensorboardX
# !apt-get -qq install sox
# !apt-get install pv
# !apt-get install jq
# !wget https://raw.githubusercontent.com/tonikelope/megadown/master/megadown -O megadown.sh
# !chmod 755 megadown.sh
#Download NVIDIA's LJSpeech model
# Download NVIDIA's LJSpeech model using wget
tt2_pretrained_url = "https://github.com/justinjohn0306/ARPAtaco2/releases/download/pretrained_model/tacotron2_statedict.pt"
tt2_pretrained_path = "/content/TTS-TT2/tacotron2_statedict.pt"

if not os.path.isfile(tt2_pretrained_path):
  print("Downloading tt2 pretrained model using wget")
  # !wget {tt2_pretrained_url} -O {tt2_pretrained_path}


#tt2_pretrained = "https://drive.google.com/uc?id=1c5ZTuT7J08wLUoVZ2KkUs_VdZuJ86ZqA"
#if not os.path.isfile("/content/TTS-TT2/pretrained_model"):
  #print("Downloading tt2 pretrained")
  #gdown.download(tt2_pretrained, "/content/TTS-TT2/pretrained_model", quiet=False)

latest_downloaded = None

import time
import logging

logging.getLogger('matplotlib').setLevel(logging.WARNING)
logging.getLogger('numba').setLevel(logging.WARNING)
logging.getLogger('librosa').setLevel(logging.WARNING)


import argparse
import math
from numpy import finfo

import torch
from distributed import apply_gradient_allreduce
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
from torch.utils.data import DataLoader

from model import Tacotron2
from data_utils import TextMelLoader, TextMelCollate
from loss_function import Tacotron2Loss
from logger import Tacotron2Logger
from hparams import create_hparams

import random
import numpy as np

import layers
from utils import load_wav_to_torch, load_filepaths_and_text
from text import text_to_sequence
from math import e
#from tqdm import tqdm # Terminal
#from tqdm import tqdm_notebook as tqdm # Legacy Notebook TQDM
from tqdm.notebook import tqdm # Modern Notebook TQDM
from distutils.dir_util import copy_tree
import matplotlib.pylab as plt

def download_from_google_drive(file_id, file_name):
  # download a file from the Google Drive link
  # !rm -f ./cookie
  # !curl -c ./cookie -s -L "https://drive.google.com/uc?export=download&id={file_id}" > /dev/null
  confirm_text = !awk '/download/ {print $NF}' ./cookie
  confirm_text = confirm_text[0]
  # !curl -Lb ./cookie "https://drive.google.com/uc?export=download&confirm={confirm_text}&id={file_id}" -o {file_name}

def create_mels():
    print("Generating Mels")
    stft = layers.TacotronSTFT(
                hparams.filter_length, hparams.hop_length, hparams.win_length,
                hparams.n_mel_channels, hparams.sampling_rate, hparams.mel_fmin,
                hparams.mel_fmax)
    def save_mel(filename):
        audio, sampling_rate = load_wav_to_torch(filename)
        if sampling_rate != stft.sampling_rate:
            raise ValueError("{} {} SR doesn't match target {} SR".format(filename,
                sampling_rate, stft.sampling_rate))
        audio_norm = audio / hparams.max_wav_value
        audio_norm = audio_norm.unsqueeze(0)
        audio_norm = torch.autograd.Variable(audio_norm, requires_grad=False)
        melspec = stft.mel_spectrogram(audio_norm)
        melspec = torch.squeeze(melspec, 0).cpu().numpy()
        np.save(filename.replace('.wav', ''), melspec)

    import glob
    wavs = glob.glob('wavs/*.wav')
    for i in tqdm(wavs):
        save_mel(i)


def reduce_tensor(tensor, n_gpus):
    rt = tensor.clone()
    dist.all_reduce(rt, op=dist.reduce_op.SUM)
    rt /= n_gpus
    return rt


def init_distributed(hparams, n_gpus, rank, group_name):
    assert torch.cuda.is_available(), "Distributed mode requires CUDA."
    print("Initializing Distributed")

    # Set cuda device so everything is done on the right GPU.
    torch.cuda.set_device(rank % torch.cuda.device_count())

    # Initialize distributed communication
    dist.init_process_group(
        backend=hparams.dist_backend, init_method=hparams.dist_url,
        world_size=n_gpus, rank=rank, group_name=group_name)

    print("Done initializing distributed")


def prepare_dataloaders(hparams):
    # Get data, data loaders and collate function ready
    trainset = TextMelLoader(hparams.training_files, hparams)
    valset = TextMelLoader(hparams.validation_files, hparams)
    collate_fn = TextMelCollate(hparams.n_frames_per_step)

    if hparams.distributed_run:
        train_sampler = DistributedSampler(trainset)
        shuffle = False
    else:
        train_sampler = None
        shuffle = True

    train_loader = DataLoader(trainset, num_workers=1, shuffle=shuffle,
                              sampler=train_sampler,
                              batch_size=hparams.batch_size, pin_memory=False,
                              drop_last=True, collate_fn=collate_fn)
    return train_loader, valset, collate_fn


def prepare_directories_and_logger(output_directory, log_directory, rank):
    if rank == 0:
        if not os.path.isdir(output_directory):
            os.makedirs(output_directory)
            os.chmod(output_directory, 0o775)
        logger = Tacotron2Logger(os.path.join(output_directory, log_directory))
    else:
        logger = None
    return logger


def load_model(hparams):
    model = Tacotron2(hparams).cuda()
    if hparams.fp16_run:
        model.decoder.attention_layer.score_mask_value = finfo('float16').min

    if hparams.distributed_run:
        model = apply_gradient_allreduce(model)

    return model


def warm_start_model(checkpoint_path, model, ignore_layers):
    assert os.path.isfile(checkpoint_path)
    print("Warm starting model from checkpoint '{}'".format(checkpoint_path))
    checkpoint_dict = torch.load(checkpoint_path, map_location='cpu')
    model_dict = checkpoint_dict['state_dict']
    if len(ignore_layers) > 0:
        model_dict = {k: v for k, v in model_dict.items()
                      if k not in ignore_layers}
        dummy_dict = model.state_dict()
        dummy_dict.update(model_dict)
        model_dict = dummy_dict
    model.load_state_dict(model_dict)
    return model


def load_checkpoint(checkpoint_path, model, optimizer):
    assert os.path.isfile(checkpoint_path)
    print("Loading checkpoint '{}'".format(checkpoint_path))
    checkpoint_dict = torch.load(checkpoint_path, map_location='cpu')
    model.load_state_dict(checkpoint_dict['state_dict'])
    optimizer.load_state_dict(checkpoint_dict['optimizer'])
    learning_rate = checkpoint_dict['learning_rate']
    iteration = checkpoint_dict['iteration']
    print("Loaded checkpoint '{}' from iteration {}" .format(
        checkpoint_path, iteration))
    return model, optimizer, learning_rate, iteration


def save_checkpoint(model, optimizer, learning_rate, iteration, filepath):
    import random
    if True:
        print("Saving model and optimizer state at iteration {} to {}".format(
            iteration, filepath))
        try:
            torch.save({'iteration': iteration,
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'learning_rate': learning_rate}, filepath)
        except KeyboardInterrupt:
            print("interrupt received while saving, waiting for save to complete.")
            torch.save({'iteration': iteration,'state_dict': model.state_dict(),'optimizer': optimizer.state_dict(),'learning_rate': learning_rate}, filepath)
        print("Model Saved")

def plot_alignment(alignment, info=None):
    # %matplotlib inline
    fig, ax = plt.subplots(figsize=(int(alignment_graph_width/100), int(alignment_graph_height/100)))
    im = ax.imshow(alignment, cmap='inferno', aspect='auto', origin='lower',
                   interpolation='none')
    ax.autoscale(enable=True, axis="y", tight=True)
    fig.colorbar(im, ax=ax)
    xlabel = 'Decoder timestep'
    if info is not None:
        xlabel += '\n\n' + info
    plt.xlabel(xlabel)
    plt.ylabel('Encoder timestep')
    plt.tight_layout()
    fig.canvas.draw()
    plt.show()

def validate(model, criterion, valset, iteration, batch_size, n_gpus,
             collate_fn, logger, distributed_run, rank, epoch, start_eposh, learning_rate):
    """Handles all the validation scoring and printing"""
    model.eval()
    with torch.no_grad():
        val_sampler = DistributedSampler(valset) if distributed_run else None
        val_loader = DataLoader(valset, sampler=val_sampler, num_workers=1,
                                shuffle=False, batch_size=batch_size,
                                pin_memory=False, collate_fn=collate_fn)

        val_loss = 0.0
        for i, batch in enumerate(val_loader):
            x, y = model.parse_batch(batch)
            y_pred = model(x)
            loss = criterion(y_pred, y)
            if distributed_run:
                reduced_val_loss = reduce_tensor(loss.data, n_gpus).item()
            else:
                reduced_val_loss = loss.item()
            val_loss += reduced_val_loss
        val_loss = val_loss / (i + 1)

    model.train()
    if rank == 0:
        print("Epoch: {} Validation loss {}: {:9f}  Time: {:.1f}m LR: {:.6f}".format(epoch, iteration, val_loss,(time.perf_counter()-start_eposh)/60, learning_rate))
        logger.log_validation(val_loss, model, y, y_pred, iteration)
        if hparams.show_alignments:
            # %matplotlib inline
            _, mel_outputs, gate_outputs, alignments = y_pred
            idx = random.randint(0, alignments.size(0) - 1)
            plot_alignment(alignments[idx].data.cpu().numpy().T)

def train(output_directory, log_directory, checkpoint_path, warm_start, n_gpus,
          rank, group_name, hparams, log_directory2, save_interval, backup_interval):
    """Training and validation logging results to tensorboard and stdout

    Params
    ------
    output_directory (string): directory to save checkpoints
    log_directory (string) directory to save tensorboard logs
    checkpoint_path(string): checkpoint path
    n_gpus (int): number of gpus
    rank (int): rank of current gpu
    hparams (object): comma separated list of "name=value" pairs.
    """
    if hparams.distributed_run:
        init_distributed(hparams, n_gpus, rank, group_name)

    torch.manual_seed(hparams.seed)
    torch.cuda.manual_seed(hparams.seed)

    model = load_model(hparams)
    learning_rate = hparams.learning_rate
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                                 weight_decay=hparams.weight_decay)

    if hparams.fp16_run:
        from apex import amp
        model, optimizer = amp.initialize(
            model, optimizer, opt_level='O2')

    if hparams.distributed_run:
        model = apply_gradient_allreduce(model)

    criterion = Tacotron2Loss()

    logger = prepare_directories_and_logger(
        output_directory, log_directory, rank)

    train_loader, valset, collate_fn = prepare_dataloaders(hparams)

    # Load checkpoint if one exists
    iteration = 0
    epoch_offset = 0
    if checkpoint_path is not None and os.path.isfile(checkpoint_path):
        if warm_start:
            model = warm_start_model(
                checkpoint_path, model, hparams.ignore_layers)
        else:
            model, optimizer, _learning_rate, iteration = load_checkpoint(
                checkpoint_path, model, optimizer)
            if hparams.use_saved_learning_rate:
                learning_rate = _learning_rate
            iteration += 1  # next iteration is iteration + 1
            epoch_offset = max(0, int(iteration / len(train_loader)))
    else:
      os.path.isfile("/content/TTS-TT2/pretrained_model")
      # %cd /dev/null
      # !/content/TTS-TT2/megadown.sh https://mega.nz/#!WXY3RILA!KyoGHtfB_sdhmLFoykG2lKWhh0GFdwMkk7OwAjpQHRo --o pretrained_model
      # %cd /content/TTS-TT2
      model = warm_start_model("/content/TTS-TT2/pretrained_model", model, hparams.ignore_layers)
      # download LJSpeech pretrained model if no checkpoint already exists

    start_eposh = time.perf_counter()
    learning_rate = 0.0
    model.train()
    is_overflow = False
    # ================ MAIN TRAINNIG LOOP! ===================
    for epoch in tqdm(range(epoch_offset, hparams.epochs)):
        print("\nStarting Epoch: {} Iteration: {}".format(epoch, iteration))
        start_eposh = time.perf_counter() # eposh is russian, not a typo
        for i, batch in tqdm(enumerate(train_loader), total=len(train_loader)):
            start = time.perf_counter()
            if iteration < hparams.decay_start: learning_rate = hparams.A_
            else: iteration_adjusted = iteration - hparams.decay_start; learning_rate = (hparams.A_*(e**(-iteration_adjusted/hparams.B_))) + hparams.C_
            learning_rate = max(hparams.min_learning_rate, learning_rate) # output the largest number
            for param_group in optimizer.param_groups:
                param_group['lr'] = learning_rate

            model.zero_grad()
            x, y = model.parse_batch(batch)
            y_pred = model(x)

            loss = criterion(y_pred, y)
            if hparams.distributed_run:
                reduced_loss = reduce_tensor(loss.data, n_gpus).item()
            else:
                reduced_loss = loss.item()
            if hparams.fp16_run:
                with amp.scale_loss(loss, optimizer) as scaled_loss:
                    scaled_loss.backward()
            else:
                loss.backward()

            if hparams.fp16_run:
                grad_norm = torch.nn.utils.clip_grad_norm_(
                    amp.master_params(optimizer), hparams.grad_clip_thresh)
                is_overflow = math.isnan(grad_norm)
            else:
                grad_norm = torch.nn.utils.clip_grad_norm_(
                    model.parameters(), hparams.grad_clip_thresh)

            optimizer.step()

            if not is_overflow and rank == 0:
                duration = time.perf_counter() - start
                logger.log_training(
                    reduced_loss, grad_norm, learning_rate, duration, iteration)
                #print("Batch {} loss {:.6f} Grad Norm {:.6f} Time {:.6f}".format(iteration, reduced_loss, grad_norm, duration), end='\r', flush=True)

            iteration += 1
        validate(model, criterion, valset, iteration,
                 hparams.batch_size, n_gpus, collate_fn, logger,
                 hparams.distributed_run, rank, epoch, start_eposh, learning_rate)
        if (epoch+1) % save_interval == 0 or (epoch+1) == hparams.epochs: # not sure if the latter is necessary
            save_checkpoint(model, optimizer, learning_rate, iteration, checkpoint_path)
        if backup_interval > 0 and (epoch+1) % backup_interval == 0:
            save_checkpoint(model, optimizer, learning_rate, iteration, checkpoint_path + "_epoch_%s" % (epoch+1))
        if log_directory2 != None:
            copy_tree(log_directory, log_directory2)
def check_dataset(hparams):
    from utils import load_wav_to_torch, load_filepaths_and_text
    import os
    import numpy as np
    def check_arr(filelist_arr):
        for i, file in enumerate(filelist_arr):
            if len(file) > 2:
                print("|".join(file), "\nhas multiple '|', this may not be an error.")
            if hparams.load_mel_from_disk and '.wav' in file[0]:
                print("[WARNING]", file[0], " in filelist while expecting .npy .")
            else:
                if not hparams.load_mel_from_disk and '.npy' in file[0]:
                    print("[WARNING]", file[0], " in filelist while expecting .wav .")
            if (not os.path.exists(file[0])):
                print("|".join(file), "\n[WARNING] does not exist.")
            if len(file[1]) < 3:
                print("|".join(file), "\n[info] has no/very little text.")
            if not ((file[1].strip())[-1] in r"!?,.;:"):
                print("|".join(file), "\n[info] has no ending punctuation.")
            mel_length = 1
            if hparams.load_mel_from_disk and '.npy' in file[0]:
                melspec = torch.from_numpy(np.load(file[0], allow_pickle=True))
                mel_length = melspec.shape[1]
            if mel_length == 0:
                print("|".join(file), "\n[WARNING] has 0 duration.")
    print("Checking Training Files")
    audiopaths_and_text = load_filepaths_and_text(hparams.training_files) # get split lines from training_files text file.
    check_arr(audiopaths_and_text)
    print("Checking Validation Files")
    audiopaths_and_text = load_filepaths_and_text(hparams.validation_files) # get split lines from validation_files text file.
    check_arr(audiopaths_and_text)
    print("Finished Checking")

warm_start=False#sorry bout that
n_gpus=1
rank=0
group_name=None

# ---- DEFAULT PARAMETERS DEFINED HERE ----
hparams = create_hparams()
model_filename = 'current_model'
hparams.training_files = "filelists/clipper_train_filelist.txt"
hparams.validation_files = "filelists/clipper_val_filelist.txt"
#hparams.use_mmi=True,          # not used in this notebook
#hparams.use_gaf=True,          # not used in this notebook
#hparams.max_gaf=0.5,           # not used in this notebook
#hparams.drop_frame_rate = 0.2  # not used in this notebook
hparams.p_attention_dropout=0.1
hparams.p_decoder_dropout=0.1
hparams.decay_start = 15000
hparams.A_ = 5e-4
hparams.B_ = 8000
hparams.C_ = 0
hparams.min_learning_rate = 1e-5
generate_mels = True
hparams.show_alignments = True
alignment_graph_height = 600
alignment_graph_width = 1000
hparams.batch_size = 32
hparams.load_mel_from_disk = True
hparams.ignore_layers = []
hparams.epochs = 10000
torch.backends.cudnn.enabled = hparams.cudnn_enabled
torch.backends.cudnn.benchmark = hparams.cudnn_benchmark
output_directory = '/content/drive/My Drive/colab/outdir' # Location to save Checkpoints
log_directory = '/content/TTS-TT2/logs' # Location to save Log files locally
log_directory2 = '/content/drive/My Drive/colab/logs' # Location to copy log files (done at the end of each epoch to cut down on I/O)
checkpoint_path = output_directory+(r'/')+model_filename

# ---- Replace .wav with .npy in filelists ----
# !sed -i -- 's,.wav|,.npy|,g' filelists/*.txt
# !sed -i -- 's,.wav|,.npy|,g' {hparams.training_files}
# !sed -i -- 's,.wav|,.npy|,g' {hparams.validation_files}
# ---- Replace .wav with .npy in filelists ----

# %cd /content/TTS-TT2

data_path = 'wavs'
# !mkdir {data_path}
# Out:
# /content
# Cloning justinjohn0306/TTS-TT2
# Cloning into 'TTS-TT2'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 93 (delta 3), reused 1 (delta 0), pack-reused 80 (from 1)
# Receiving objects: 100% (93/93), 7.12 MiB | 9.72 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/TTS-TT2
# /content/TTS-TT2
# Downloading tacotron2 requirements
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: inflect in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Collecting Unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect) (4.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard>=4.0.1->inflect) (4.15.0)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 10.6 MB/s eta 0:00:00
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.4.0
# Collecting git+https://github.com/wkentaro/gdown.git
#   Cloning https://github.com/wkentaro/gdown.git to /tmp/pip-req-build-_qqeqn97
#   Running command git clone --filter=blob:none --quiet https://github.com/wkentaro/gdown.git /tmp/pip-req-build-_qqeqn97
#   Resolved https://github.com/wkentaro/gdown.git to commit c7c1b9d2bae2be11112bbe88de1f64ac90416cf2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.1.dev6+gc7c1b9d2b) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.1.dev6+gc7c1b9d2b) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.1.dev6+gc7c1b9d2b) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.1.dev6+gc7c1b9d2b) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==5.2.1.dev6+gc7c1b9d2b) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==5.2.1.dev6+gc7c1b9d2b) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.1.dev6+gc7c1b9d2b) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.1.dev6+gc7c1b9d2b) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.1.dev6+gc7c1b9d2b) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.1.dev6+gc7c1b9d2b) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.1.dev6+gc7c1b9d2b) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-5.2.1.dev6+gc7c1b9d2b-py3-none-any.whl size=18426 sha256=32ee789997262aaaf78567fa69cd6cce515e8b635e3f430debaa80e9553663f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uey9v87r/wheels/1f/ea/70/7b5926a2c8639bbaba6ff1649e1b471f016f5fd951b1eb38a6
# Successfully built gdown
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# Successfully installed gdown-5.2.1.dev6+gc7c1b9d2b
# Collecting ffmpeg-normalize
#   Downloading ffmpeg_normalize-1.33.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from ffmpeg-normalize) (4.67.1)
# Collecting ffmpeg-progress-yield>=1.0.1 (from ffmpeg-normalize)
#   Downloading ffmpeg_progress_yield-1.0.3-py3-none-any.whl.metadata (11 kB)
# Collecting colorlog==6.7.0 (from ffmpeg-normalize)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting mutagen>=1.47.0 (from ffmpeg-normalize)
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Downloading ffmpeg_normalize-1.33.1-py3-none-any.whl (28 kB)
# Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Downloading ffmpeg_progress_yield-1.0.3-py3-none-any.whl (12 kB)
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: mutagen, ffmpeg-progress-yield, colorlog, ffmpeg-normalize
# Successfully installed colorlog-6.7.0 ffmpeg-normalize-1.33.1 ffmpeg-progress-yield-1.0.3 mutagen-1.47.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.2 MB/s eta 0:00:00
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 126435 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../2-libsox3_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../3-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../4-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../5-libsox-fmt-base_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../6-sox_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   doc-base
# The following NEW packages will be installed:
#   pv
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 44.5 kB of archives.
# After this operation, 139 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pv amd64 1.6.6-1build2 [44.5 kB]
# Fetched 44.5 kB in 0s (856 kB/s)
# Selecting previously unselected package pv.
# (Reading database ... 126508 files and directories currently installed.)
# Preparing to unpack .../pv_1.6.6-1build2_amd64.deb ...
# Unpacking pv (1.6.6-1build2) ...
# Setting up pv (1.6.6-1build2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# jq is already the newest version (1.6-2.1ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# --2025-09-20 11:44:01--  https://raw.githubusercontent.com/tonikelope/megadown/master/megadown
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17043 (17K) [text/plain]
# Saving to: ‘megadown.sh’
#
# megadown.sh         100%[===================>]  16.64K  --.-KB/s    in 0.001s
#
# 2025-09-20 11:44:01 (28.5 MB/s) - ‘megadown.sh’ saved [17043/17043]
#
# Downloading tt2 pretrained model using wget
# --2025-09-20 11:44:01--  https://github.com/justinjohn0306/ARPAtaco2/releases/download/pretrained_model/tacotron2_statedict.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/659617282/e7cd481b-4369-4d97-a5cd-8d541cddc7f8?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-20T12%3A26%3A41Z&rscd=attachment%3B+filename%3Dtacotron2_statedict.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-20T11%3A26%3A21Z&ske=2025-09-20T12%3A26%3A41Z&sks=b&skv=2018-11-09&sig=Y0Sut6A2sXTcPndD3Yl8msqUEpBKisISA7KZ%2FM%2FoTnk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1ODM2ODk0MSwibmJmIjoxNzU4MzY4NjQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ouV96TdMjya1ZpTq-BhD-8MFtLKgP09kHsviu7z0uXg&response-content-disposition=attachment%3B%20filename%3Dtacotron2_statedict.pt&response-content-type=application%2Foctet-stream [following]
# --2025-09-20 11:44:01--  https://release-assets.githubusercontent.com/github-production-release-asset/659617282/e7cd481b-4369-4d97-a5cd-8d541cddc7f8?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-20T12%3A26%3A41Z&rscd=attachment%3B+filename%3Dtacotron2_statedict.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-20T11%3A26%3A21Z&ske=2025-09-20T12%3A26%3A41Z&sks=b&skv=2018-11-09&sig=Y0Sut6A2sXTcPndD3Yl8msqUEpBKisISA7KZ%2FM%2FoTnk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1ODM2ODk0MSwibmJmIjoxNzU4MzY4NjQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ouV96TdMjya1ZpTq-BhD-8MFtLKgP09kHsviu7z0uXg&response-content-disposition=attachment%3B%20filename%3Dtacotron2_statedict.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112818746 (108M) [application/octet-stream]
# Saving to: ‘/content/TTS-TT2/tacotron2_statedict.pt’
#
# /content/TTS-TT2/ta 100%[===================>] 107.59M  29.3MB/s    in 3.7s
#
# 2025-09-20 11:44:05 (29.3 MB/s) - ‘/content/TTS-TT2/tacotron2_statedict.pt’ saved [112818746/112818746]
# /content/TTS-TT2/text/__init__.py:84: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   return s in _symbol_to_id and s is not '_' and s is not '~'
# /content/TTS-TT2/text/__init__.py:84: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   return s in _symbol_to_id and s is not '_' and s is not '~'
# sed: can't read filelists/clipper_train_filelist.txt: No such file or directory
# sed: can't read filelists/clipper_val_filelist.txt: No such file or directory
# /content/TTS-TT2

# %%
# 4. Import Libraries
import os, glob, torch
from pathlib import Path
from train import train
from hparams import create_hparams
from text import symbols
from data_utils import TextMelLoader, TextMelCollate
from model import Tacotron2

# %%
# !unzip "/content/drive/MyDrive/wavs.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: wavs/55.wav
#   inflating: wavs/550.wav
#   inflating: wavs/5500.wav
#   inflating: wavs/5501.wav
#   inflating: wavs/5502.wav
#   inflating: wavs/5503.wav
#   inflating: wavs/5504.wav
#   inflating: wavs/5505.wav
#   inflating: wavs/5506.wav
#   inflating: wavs/5507.wav
#   inflating: wavs/5508.wav
#   inflating: wavs/5509.wav
#   inflating: wavs/551.wav
#   inflating: wavs/5510.wav
#   inflating: wavs/5511.wav
#   inflating: wavs/5512.wav
#   inflating: wavs/5513.wav
#   inflating: wavs/5514.wav
#   inflating: wavs/5515.wav
#   inflating: wavs/5516.wav
#   inflating: wavs/5517.wav
#   inflating: wavs/5518.wav
#   inflating: wavs/5519.wav
#   inflating: wavs/552.wav
#   inflating: wavs/5520.wav
#   inflating: wavs/5521.wav
#   inflating: wavs/5522.wav
#   inflating: wavs/5523.wav
#   inflating: wavs/5524.wav
#   inflating: wavs/5525.wav
#   inflating: wavs/5526.wav
#   inflating: wavs/5527.wav
#   inflating: wavs/5528.wav
#   inflating: wavs/5529.wav
#   inflating: wavs/553.wav
#   inflating: wavs/5530.wav
#   inflating: wavs/5531.wav
#   inflating: wavs/5532.wav
#   inflating: wavs/5533.wav
#   inflating: wavs/5534.wav
#   inflating: wavs/5535.wav
#   inflating: wavs/5536.wav
#   inflating: wavs/5537.wav
#   inflating: wavs/5538.wav
#   inflating: wavs/5539.wav
#   inflating: wavs/554.wav
#   inflating: wavs/5540.wav
#   inflating: wavs/5541.wav
#   inflating: wavs/5542.wav
#   inflating: wavs/5543.wav
#   inflating: wavs/5544.wav
#   inflating: wavs/5545.wav
#   inflating: wavs/5546.wav
#   inflating: wavs/5547.wav
#   inflating: wavs/5548.wav
#   inflating: wavs/5549.wav
#   inflating: wavs/555.wav
#   inflating: wavs/5550.wav
#   inflating: wavs/5551.wav
#   inflating: wavs/5552.wav
#   inflating: wavs/5553.wav
#   inflating: wavs/5554.wav
#   inflating: wavs/5555.wav
#   inflating: wavs/5556.wav
#   inflating: wavs/5557.wav
#   inflating: wavs/5558.wav
#   inflating: wavs/5559.wav
#   inflating: wavs/556.wav
#   inflating: wavs/5560.wav
#   inflating: wavs/5561.wav
#   inflating: wavs/5562.wav
#   inflating: wavs/5563.wav
#   inflating: wavs/5564.wav
#   inflating: wavs/5565.wav
#   inflating: wavs/5566.wav
#   inflating: wavs/5567.wav
#   inflating: wavs/5568.wav
#   inflating: wavs/5569.wav
#   inflating: wavs/557.wav
#   inflating: wavs/5570.wav
#   inflating: wavs/5571.wav
#   inflating: wavs/5572.wav
#   inflating: wavs/5573.wav
#   inflating: wavs/5574.wav
#   inflating: wavs/5575.wav
#   inflating: wavs/5576.wav
#   inflating: wavs/5577.wav
#   inflating: wavs/5578.wav
#   inflating: wavs/5579.wav
#   inflating: wavs/558.wav
#   inflating: wavs/5580.wav
#   inflating: wavs/5581.wav
#   inflating: wavs/5582.wav
#   inflating: wavs/5583.wav
#   inflating: wavs/5584.wav
#   inflating: wavs/5585.wav
#   inflating: wavs/5586.wav
#   inflating: wavs/5587.wav
#   inflating: wavs/5588.wav
#   inflating: wavs/5589.wav
#   inflating: wavs/559.wav
#   inflating: wavs/5590.wav
#   inflating: wavs/5591.wav
#   inflating: wavs/5592.wav
#   inflating: wavs/5593.wav
#   inflating: wavs/5594.wav
#   inflating: wavs/5595.wav
#   inflating: wavs/5596.wav
#   inflating: wavs/5597.wav
#   inflating: wavs/5598.wav
#   inflating: wavs/5599.wav
#   inflating: wavs/56.wav
#   inflating: wavs/560.wav
#   inflating: wavs/5600.wav
#   inflating: wavs/5601.wav
#   inflating: wavs/5602.wav
#   inflating: wavs/5603.wav
#   inflating: wavs/5604.wav
#   inflating: wavs/5605.wav
#   inflating: wavs/5606.wav
#   inflating: wavs/5607.wav
#   inflating: wavs/5608.wav
#   inflating: wavs/5609.wav
#   inflating: wavs/561.wav
#   inflating: wavs/5610.wav
#   inflating: wavs/5611.wav
#   inflating: wavs/5612.wav
#   inflating: wavs/5613.wav
#   inflating: wavs/5614.wav
#   inflating: wavs/5615.wav
#   inflating: wavs/5616.wav
#   inflating: wavs/5617.wav
#   inflating: wavs/5618.wav
#   inflating: wavs/5619.wav
#   inflating: wavs/562.wav
#   inflating: wavs/5620.wav
#   inflating: wavs/5621.wav
#   inflating: wavs/5622.wav
#   inflating: wavs/5623.wav
#   inflating: wavs/5624.wav
#   inflating: wavs/5625.wav
#   inflating: wavs/5626.wav
#   inflating: wavs/5627.wav
#   inflating: wavs/5628.wav
#   inflating: wavs/5629.wav
#   inflating: wavs/563.wav
#   inflating: wavs/5630.wav
#   inflating: wavs/5631.wav
#   inflating: wavs/5632.wav
#   inflating: wavs/5633.wav
#   inflating: wavs/5634.wav
#   inflating: wavs/5635.wav
#   inflating: wavs/5636.wav
#   inflating: wavs/5637.wav
#   inflating: wavs/5638.wav
#   inflating: wavs/5639.wav
#   inflating: wavs/564.wav
#   inflating: wavs/5640.wav
#   inflating: wavs/5641.wav
#   inflating: wavs/5642.wav
#   inflating: wavs/5643.wav
#   inflating: wavs/5644.wav
#   inflating: wavs/5645.wav
#   inflating: wavs/5646.wav
#   inflating: wavs/5647.wav
#   inflating: wavs/5648.wav
#   inflating: wavs/5649.wav
#   inflating: wavs/565.wav
#   inflating: wavs/5650.wav
#   inflating: wavs/5651.wav
#   inflating: wavs/5652.wav
#   inflating: wavs/5653.wav
#   inflating: wavs/5654.wav
#   inflating: wavs/5655.wav
#   inflating: wavs/5656.wav
#   inflating: wavs/5657.wav
#   inflating: wavs/5658.wav
#   inflating: wavs/5659.wav
#   inflating: wavs/566.wav
#   inflating: wavs/5660.wav
#   inflating: wavs/5661.wav
#   inflating: wavs/5662.wav
#   inflating: wavs/5663.wav
#   inflating: wavs/5664.wav
#   inflating: wavs/5665.wav
#   inflating: wavs/5666.wav
#   inflating: wavs/5667.wav
#   inflating: wavs/5668.wav
#   inflating: wavs/5669.wav
#   inflating: wavs/567.wav
#   inflating: wavs/5670.wav
#   inflating: wavs/5671.wav
#   inflating: wavs/5672.wav
#   inflating: wavs/5673.wav
#   inflating: wavs/5674.wav
#   inflating: wavs/5675.wav
#   inflating: wavs/5676.wav
#   inflating: wavs/5677.wav
#   inflating: wavs/5678.wav
#   inflating: wavs/5679.wav
#   inflating: wavs/568.wav
#   inflating: wavs/5680.wav
#   inflating: wavs/5681.wav
#   inflating: wavs/5682.wav
#   inflating: wavs/5683.wav
#   inflating: wavs/5684.wav
#   inflating: wavs/5685.wav
#   inflating: wavs/5686.wav
#   inflating: wavs/5687.wav
#   inflating: wavs/5688.wav
#   inflating: wavs/5689.wav
#   inflating: wavs/569.wav
#   inflating: wavs/5690.wav
#   inflating: wavs/5691.wav
#   inflating: wavs/5692.wav
#   inflating: wavs/5693.wav
#   inflating: wavs/5694.wav
#   inflating: wavs/5695.wav
#   inflating: wavs/5696.wav
#   inflating: wavs/5697.wav
#   inflating: wavs/5698.wav
#   inflating: wavs/5699.wav
#   inflating: wavs/57.wav
#   inflating: wavs/570.wav
#   inflating: wavs/5700.wav
#   inflating: wavs/5701.wav
#   inflating: wavs/5702.wav
#   inflating: wavs/5703.wav
#   inflating: wavs/5704.wav
#   inflating: wavs/5705.wav
#   inflating: wavs/5706.wav
#   inflating: wavs/5707.wav
#   inflating: wavs/5708.wav
#   inflating: wavs/5709.wav
#   inflating: wavs/571.wav
#   inflating: wavs/5710.wav
#   inflating: wavs/5711.wav
#   inflating: wavs/5712.wav
#   inflating: wavs/5713.wav
#   inflating: wavs/5714.wav
#   inflating: wavs/5715.wav
#   inflating: wavs/5716.wav
#   inflating: wavs/5717.wav
#   inflating: wavs/5718.wav
#   inflating: wavs/5719.wav
#   inflating: wavs/572.wav
#   inflating: wavs/5720.wav
#   inflating: wavs/5721.wav
#   inflating: wavs/5722.wav
#   inflating: wavs/5723.wav
#   inflating: wavs/5724.wav
#   inflating: wavs/5725.wav
#   inflating: wavs/5726.wav
#   inflating: wavs/5727.wav
#   inflating: wavs/5728.wav
#   inflating: wavs/5729.wav
#   inflating: wavs/573.wav
#   inflating: wavs/5730.wav
#   inflating: wavs/5731.wav
#   inflating: wavs/5732.wav
#   inflating: wavs/5733.wav
#   inflating: wavs/5734.wav
#   inflating: wavs/5735.wav
#   inflating: wavs/5736.wav
#   inflating: wavs/5737.wav
#   inflating: wavs/5738.wav
#   inflating: wavs/5739.wav
#   inflating: wavs/574.wav
#   inflating: wavs/5740.wav
#   inflating: wavs/5741.wav
#   inflating: wavs/5742.wav
#   inflating: wavs/5743.wav
#   inflating: wavs/5744.wav
#   inflating: wavs/5745.wav
#   inflating: wavs/5746.wav
#   inflating: wavs/5747.wav
#   inflating: wavs/5748.wav
#   inflating: wavs/5749.wav
#   inflating: wavs/575.wav
#   inflating: wavs/5750.wav
#   inflating: wavs/5751.wav
#   inflating: wavs/5752.wav
#   inflating: wavs/5753.wav
#   inflating: wavs/5754.wav
#   inflating: wavs/5755.wav
#   inflating: wavs/5756.wav
#   inflating: wavs/5757.wav
#   inflating: wavs/5758.wav
#   inflating: wavs/5759.wav
#   inflating: wavs/576.wav
#   inflating: wavs/5760.wav
#   inflating: wavs/5761.wav
#   inflating: wavs/5762.wav
#   inflating: wavs/5763.wav
#   inflating: wavs/5764.wav
#   inflating: wavs/5765.wav
#   inflating: wavs/5766.wav
#   inflating: wavs/5767.wav
#   inflating: wavs/5768.wav
#   inflating: wavs/5769.wav
#   inflating: wavs/577.wav
#   inflating: wavs/5770.wav
#   inflating: wavs/5771.wav
#   inflating: wavs/5772.wav
#   inflating: wavs/5773.wav
#   inflating: wavs/5774.wav
#   inflating: wavs/5775.wav
#   inflating: wavs/5776.wav
#   inflating: wavs/5777.wav
#   inflating: wavs/5778.wav
#   inflating: wavs/5779.wav
#   inflating: wavs/578.wav
#   inflating: wavs/5780.wav
#   inflating: wavs/5781.wav
#   inflating: wavs/5782.wav
#   inflating: wavs/5783.wav
#   inflating: wavs/5784.wav
#   inflating: wavs/5785.wav
#   inflating: wavs/5786.wav
#   inflating: wavs/5787.wav
#   inflating: wavs/5788.wav
#   inflating: wavs/5789.wav
#   inflating: wavs/579.wav
#   inflating: wavs/5790.wav
#   inflating: wavs/5791.wav
#   inflating: wavs/5792.wav
#   inflating: wavs/5793.wav
#   inflating: wavs/5794.wav
#   inflating: wavs/5795.wav
#   inflating: wavs/5796.wav
#   inflating: wavs/5797.wav
#   inflating: wavs/5798.wav
#   inflating: wavs/5799.wav
#   inflating: wavs/58.wav
#   inflating: wavs/580.wav
#   inflating: wavs/5800.wav
#   inflating: wavs/5801.wav
#   inflating: wavs/5802.wav
#   inflating: wavs/5803.wav
#   inflating: wavs/5804.wav
#   inflating: wavs/5805.wav
#   inflating: wavs/5806.wav
#   inflating: wavs/5807.wav
#   inflating: wavs/5808.wav
#   inflating: wavs/5809.wav
#   inflating: wavs/581.wav
#   inflating: wavs/5810.wav
#   inflating: wavs/5811.wav
#   inflating: wavs/5812.wav
#   inflating: wavs/5813.wav
#   inflating: wavs/5814.wav
#   inflating: wavs/5815.wav
#   inflating: wavs/5816.wav
#   inflating: wavs/5817.wav
#   inflating: wavs/5818.wav
#   inflating: wavs/5819.wav
#   inflating: wavs/582.wav
#   inflating: wavs/5820.wav
#   inflating: wavs/5821.wav
#   inflating: wavs/5822.wav
#   inflating: wavs/5823.wav
#   inflating: wavs/5824.wav
#   inflating: wavs/5825.wav
#   inflating: wavs/5826.wav
#   inflating: wavs/5827.wav
#   inflating: wavs/5828.wav
#   inflating: wavs/5829.wav
#   inflating: wavs/583.wav
#   inflating: wavs/5830.wav
#   inflating: wavs/5831.wav
#   inflating: wavs/5832.wav
#   inflating: wavs/5833.wav
#   inflating: wavs/5834.wav
#   inflating: wavs/5835.wav
#   inflating: wavs/5836.wav
#   inflating: wavs/5837.wav
#   inflating: wavs/5838.wav
#   inflating: wavs/5839.wav
#   inflating: wavs/584.wav
#   inflating: wavs/5840.wav
#   inflating: wavs/5841.wav
#   inflating: wavs/5842.wav
#   inflating: wavs/5843.wav
#   inflating: wavs/5844.wav
#   inflating: wavs/5845.wav
#   inflating: wavs/5846.wav
#   inflating: wavs/5847.wav
#   inflating: wavs/5848.wav
#   inflating: wavs/5849.wav
#   inflating: wavs/585.wav
#   inflating: wavs/5850.wav
#   inflating: wavs/5851.wav
#   inflating: wavs/5852.wav
#   inflating: wavs/5853.wav
#   inflating: wavs/5854.wav
#   inflating: wavs/5855.wav
#   inflating: wavs/5856.wav
#   inflating: wavs/5857.wav
#   inflating: wavs/5858.wav
#   inflating: wavs/5859.wav
#   inflating: wavs/586.wav
#   inflating: wavs/5860.wav
#   inflating: wavs/5861.wav
#   inflating: wavs/5862.wav
#   inflating: wavs/5863.wav
#   inflating: wavs/5864.wav
#   inflating: wavs/5865.wav
#   inflating: wavs/5866.wav
#   inflating: wavs/5867.wav
#   inflating: wavs/5868.wav
#   inflating: wavs/5869.wav
#   inflating: wavs/587.wav
#   inflating: wavs/5870.wav
#   inflating: wavs/5871.wav
#   inflating: wavs/5872.wav
#   inflating: wavs/5873.wav
#   inflating: wavs/5874.wav
#   inflating: wavs/5875.wav
#   inflating: wavs/5876.wav
#   inflating: wavs/5877.wav
#   inflating: wavs/5878.wav
#   inflating: wavs/5879.wav
#   inflating: wavs/588.wav
#   inflating: wavs/5880.wav
#   inflating: wavs/5881.wav
#   inflating: wavs/5882.wav
#   inflating: wavs/5883.wav
#   inflating: wavs/5884.wav
#   inflating: wavs/5885.wav
#   inflating: wavs/5886.wav
#   inflating: wavs/5887.wav
#   inflating: wavs/5888.wav
#   inflating: wavs/5889.wav
#   inflating: wavs/589.wav
#   inflating: wavs/5890.wav
#   inflating: wavs/5891.wav
#   inflating: wavs/5892.wav
#   inflating: wavs/5893.wav
#   inflating: wavs/5894.wav
#   inflating: wavs/5895.wav
#   inflating: wavs/5896.wav
#   inflating: wavs/5897.wav
#   inflating: wavs/5898.wav
#   inflating: wavs/5899.wav
#   inflating: wavs/59.wav
#   inflating: wavs/590.wav
#   inflating: wavs/5900.wav
#   inflating: wavs/5901.wav
#   inflating: wavs/5902.wav
#   inflating: wavs/5903.wav
#   inflating: wavs/5904.wav
#   inflating: wavs/5905.wav
#   inflating: wavs/5906.wav
#   inflating: wavs/5907.wav
#   inflating: wavs/5908.wav
#   inflating: wavs/5909.wav
#   inflating: wavs/591.wav
#   inflating: wavs/5910.wav
#   inflating: wavs/5911.wav
#   inflating: wavs/5912.wav
#   inflating: wavs/5913.wav
#   inflating: wavs/5914.wav
#   inflating: wavs/5915.wav
#   inflating: wavs/5916.wav
#   inflating: wavs/5917.wav
#   inflating: wavs/5918.wav
#   inflating: wavs/5919.wav
#   inflating: wavs/592.wav
#   inflating: wavs/5920.wav
#   inflating: wavs/5921.wav
#   inflating: wavs/5922.wav
#   inflating: wavs/5923.wav
#   inflating: wavs/5924.wav
#   inflating: wavs/5925.wav
#   inflating: wavs/5926.wav
#   inflating: wavs/5927.wav
#   inflating: wavs/5928.wav
#   inflating: wavs/5929.wav
#   inflating: wavs/593.wav
#   inflating: wavs/5930.wav
#   inflating: wavs/5931.wav
#   inflating: wavs/5932.wav
#   inflating: wavs/5933.wav
#   inflating: wavs/5934.wav
#   inflating: wavs/5935.wav
#   inflating: wavs/5936.wav
#   inflating: wavs/5937.wav
#   inflating: wavs/5938.wav
#   inflating: wavs/5939.wav
#   inflating: wavs/594.wav
#   inflating: wavs/5940.wav
#   inflating: wavs/5941.wav
#   inflating: wavs/5942.wav
#   inflating: wavs/5943.wav
#   inflating: wavs/5944.wav
#   inflating: wavs/5945.wav
#   inflating: wavs/5946.wav
#   inflating: wavs/5947.wav
#   inflating: wavs/5948.wav
#   inflating: wavs/5949.wav
#   inflating: wavs/595.wav
#   inflating: wavs/5950.wav
#   inflating: wavs/5951.wav
#   inflating: wavs/5952.wav
#   inflating: wavs/5953.wav
#   inflating: wavs/5954.wav
#   inflating: wavs/5955.wav
#   inflating: wavs/5956.wav
#   inflating: wavs/5957.wav
#   inflating: wavs/5958.wav
#   inflating: wavs/5959.wav
#   inflating: wavs/596.wav
#   inflating: wavs/5960.wav
#   inflating: wavs/5961.wav
#   inflating: wavs/5962.wav
#   inflating: wavs/5963.wav
#   inflating: wavs/5964.wav
#   inflating: wavs/5965.wav
#   inflating: wavs/5966.wav
#   inflating: wavs/5967.wav
#   inflating: wavs/5968.wav
#   inflating: wavs/5969.wav
#   inflating: wavs/597.wav
#   inflating: wavs/5970.wav
#   inflating: wavs/5971.wav
#   inflating: wavs/5972.wav
#   inflating: wavs/5973.wav
#   inflating: wavs/5974.wav
#   inflating: wavs/5975.wav
#   inflating: wavs/5976.wav
#   inflating: wavs/5977.wav
#   inflating: wavs/5978.wav
#   inflating: wavs/5979.wav
#   inflating: wavs/598.wav
#   inflating: wavs/5980.wav
#   inflating: wavs/5981.wav
#   inflating: wavs/5982.wav
#   inflating: wavs/5983.wav
#   inflating: wavs/5984.wav
#   inflating: wavs/5985.wav
#   inflating: wavs/5986.wav
#   inflating: wavs/5987.wav
#   inflating: wavs/5988.wav
#   inflating: wavs/5989.wav
#   inflating: wavs/599.wav
#   inflating: wavs/5990.wav
#   inflating: wavs/5991.wav
#   inflating: wavs/5992.wav
#   inflating: wavs/5993.wav
#   inflating: wavs/5994.wav
#   inflating: wavs/5995.wav
#   inflating: wavs/5996.wav
#   inflating: wavs/5997.wav
#   inflating: wavs/5998.wav
#   inflating: wavs/5999.wav
#   inflating: wavs/6.wav
#   inflating: wavs/60.wav
#   inflating: wavs/600.wav
#   inflating: wavs/6000.wav
#   inflating: wavs/6001.wav
#   inflating: wavs/6002.wav
#   inflating: wavs/6003.wav
#   inflating: wavs/6004.wav
#   inflating: wavs/6005.wav
#   inflating: wavs/6006.wav
#   inflating: wavs/6007.wav
#   inflating: wavs/6008.wav
#   inflating: wavs/6009.wav
#   inflating: wavs/601.wav
#   inflating: wavs/6010.wav
#   inflating: wavs/6011.wav
#   inflating: wavs/6012.wav
#   inflating: wavs/6013.wav
#   inflating: wavs/6014.wav
#   inflating: wavs/6015.wav
#   inflating: wavs/6016.wav
#   inflating: wavs/6017.wav
#   inflating: wavs/6018.wav
#   inflating: wavs/6019.wav
#   inflating: wavs/602.wav
#   inflating: wavs/6020.wav
#   inflating: wavs/6021.wav
#   inflating: wavs/6022.wav
#   inflating: wavs/6023.wav
#   inflating: wavs/6024.wav
#   inflating: wavs/6025.wav
#   inflating: wavs/6026.wav
#   inflating: wavs/6027.wav
#   inflating: wavs/6028.wav
#   inflating: wavs/6029.wav
#   inflating: wavs/603.wav
#   inflating: wavs/6030.wav
#   inflating: wavs/6031.wav
#   inflating: wavs/6032.wav
#   inflating: wavs/6033.wav
#   inflating: wavs/6034.wav
#   inflating: wavs/6035.wav
#   inflating: wavs/6036.wav
#   inflating: wavs/6037.wav
#   inflating: wavs/6038.wav
#   inflating: wavs/6039.wav
#   inflating: wavs/604.wav
#   inflating: wavs/6040.wav
#   inflating: wavs/6041.wav
#   inflating: wavs/6042.wav
#   inflating: wavs/6043.wav
#   inflating: wavs/6044.wav
#   inflating: wavs/6045.wav
#   inflating: wavs/6046.wav
#   inflating: wavs/6047.wav
#   inflating: wavs/6048.wav
#   inflating: wavs/6049.wav
#   inflating: wavs/605.wav
#   inflating: wavs/6050.wav
#   inflating: wavs/6051.wav
#   inflating: wavs/6052.wav
#   inflating: wavs/6053.wav
#   inflating: wavs/6054.wav
#   inflating: wavs/6055.wav
#   inflating: wavs/6056.wav
#   inflating: wavs/6057.wav
#   inflating: wavs/6058.wav
#   inflating: wavs/6059.wav
#   inflating: wavs/606.wav
#   inflating: wavs/6060.wav
#   inflating: wavs/6061.wav
#   inflating: wavs/6062.wav
#   inflating: wavs/6063.wav
#   inflating: wavs/6064.wav
#   inflating: wavs/6065.wav
#   inflating: wavs/6066.wav
#   inflating: wavs/6067.wav
#   inflating: wavs/6068.wav
#   inflating: wavs/6069.wav
#   inflating: wavs/607.wav
#   inflating: wavs/6070.wav
#   inflating: wavs/6071.wav
#   inflating: wavs/6072.wav
#   inflating: wavs/6073.wav
#   inflating: wavs/6074.wav
#   inflating: wavs/6075.wav
#   inflating: wavs/6076.wav
#   inflating: wavs/6077.wav
#   inflating: wavs/6078.wav
#   inflating: wavs/6079.wav
#   inflating: wavs/608.wav
#   inflating: wavs/6080.wav
#   inflating: wavs/6081.wav
#   inflating: wavs/6082.wav
#   inflating: wavs/6083.wav
#   inflating: wavs/6084.wav
#   inflating: wavs/6085.wav
#   inflating: wavs/6086.wav
#   inflating: wavs/6087.wav
#   inflating: wavs/6088.wav
#   inflating: wavs/6089.wav
#   inflating: wavs/609.wav
#   inflating: wavs/6090.wav
#   inflating: wavs/6091.wav
#   inflating: wavs/6092.wav
#   inflating: wavs/6093.wav
#   inflating: wavs/6094.wav
#   inflating: wavs/6095.wav
#   inflating: wavs/6096.wav
#   inflating: wavs/6097.wav
#   inflating: wavs/6098.wav
#   inflating: wavs/6099.wav
#   inflating: wavs/61.wav
#   inflating: wavs/610.wav
#   inflating: wavs/6100.wav
#   inflating: wavs/6101.wav
#   inflating: wavs/6102.wav
#   inflating: wavs/6103.wav
#   inflating: wavs/6104.wav
#   inflating: wavs/6105.wav
#   inflating: wavs/6106.wav
#   inflating: wavs/6107.wav
#   inflating: wavs/6108.wav
#   inflating: wavs/6109.wav
#   inflating: wavs/611.wav
#   inflating: wavs/6110.wav
#   inflating: wavs/6111.wav
#   inflating: wavs/6112.wav
#   inflating: wavs/6113.wav
#   inflating: wavs/6114.wav
#   inflating: wavs/6115.wav
#   inflating: wavs/6116.wav
#   inflating: wavs/6117.wav
#   inflating: wavs/6118.wav
#   inflating: wavs/6119.wav
#   inflating: wavs/612.wav
#   inflating: wavs/6120.wav
#   inflating: wavs/6121.wav
#   inflating: wavs/6122.wav
#   inflating: wavs/6123.wav
#   inflating: wavs/6124.wav
#   inflating: wavs/6125.wav
#   inflating: wavs/6126.wav
#   inflating: wavs/6127.wav
#   inflating: wavs/6128.wav
#   inflating: wavs/6129.wav
#   inflating: wavs/613.wav
#   inflating: wavs/6130.wav
#   inflating: wavs/6131.wav
#   inflating: wavs/6132.wav
#   inflating: wavs/6133.wav
#   inflating: wavs/6134.wav
#   inflating: wavs/6135.wav
#   inflating: wavs/6136.wav
#   inflating: wavs/6137.wav
#   inflating: wavs/6138.wav
#   inflating: wavs/6139.wav
#   inflating: wavs/614.wav
#   inflating: wavs/6140.wav
#   inflating: wavs/6141.wav
#   inflating: wavs/6142.wav
#   inflating: wavs/6143.wav
#   inflating: wavs/6144.wav
#   inflating: wavs/6145.wav
#   inflating: wavs/6146.wav
#   inflating: wavs/6147.wav
#   inflating: wavs/6148.wav
#   inflating: wavs/6149.wav
#   inflating: wavs/615.wav
#   inflating: wavs/6150.wav
#   inflating: wavs/6151.wav
#   inflating: wavs/6152.wav
#   inflating: wavs/6153.wav
#   inflating: wavs/6154.wav
#   inflating: wavs/6155.wav
#   inflating: wavs/6156.wav
#   inflating: wavs/6157.wav
#   inflating: wavs/6158.wav
#   inflating: wavs/6159.wav
#   inflating: wavs/616.wav
#   inflating: wavs/6160.wav
#   inflating: wavs/6161.wav
#   inflating: wavs/6162.wav
#   inflating: wavs/6163.wav
#   inflating: wavs/6164.wav
#   inflating: wavs/6165.wav
#   inflating: wavs/6166.wav
#   inflating: wavs/6167.wav
#   inflating: wavs/6168.wav
#   inflating: wavs/6169.wav
#   inflating: wavs/617.wav
#   inflating: wavs/6170.wav
#   inflating: wavs/6171.wav
#   inflating: wavs/6172.wav
#   inflating: wavs/6173.wav
#   inflating: wavs/6174.wav
#   inflating: wavs/6175.wav
#   inflating: wavs/6176.wav
#   inflating: wavs/6177.wav
#   inflating: wavs/6178.wav
#   inflating: wavs/6179.wav
#   inflating: wavs/618.wav
#   inflating: wavs/6180.wav
#   inflating: wavs/6181.wav
#   inflating: wavs/6182.wav
#   inflating: wavs/6183.wav
#   inflating: wavs/6184.wav
#   inflating: wavs/6185.wav
#   inflating: wavs/6186.wav
#   inflating: wavs/6187.wav
#   inflating: wavs/6188.wav
#   inflating: wavs/6189.wav
#   inflating: wavs/619.wav
#   inflating: wavs/6190.wav
#   inflating: wavs/6191.wav
#   inflating: wavs/6192.wav
#   inflating: wavs/6193.wav
#   inflating: wavs/6194.wav
#   inflating: wavs/6195.wav
#   inflating: wavs/6196.wav
#   inflating: wavs/6197.wav
#   inflating: wavs/6198.wav
#   inflating: wavs/6199.wav
#   inflating: wavs/62.wav
#   inflating: wavs/620.wav
#   inflating: wavs/6200.wav
#   inflating: wavs/6201.wav
#   inflating: wavs/6202.wav
#   inflating: wavs/6203.wav
#   inflating: wavs/6204.wav
#   inflating: wavs/6205.wav
#   inflating: wavs/6206.wav
#   inflating: wavs/6207.wav
#   inflating: wavs/6208.wav
#   inflating: wavs/6209.wav
#   inflating: wavs/621.wav
#   inflating: wavs/6210.wav
#   inflating: wavs/6211.wav
#   inflating: wavs/6212.wav
#   inflating: wavs/6213.wav
#   inflating: wavs/6214.wav
#   inflating: wavs/6215.wav
#   inflating: wavs/6216.wav
#   inflating: wavs/6217.wav
#   inflating: wavs/6218.wav
#   inflating: wavs/6219.wav
#   inflating: wavs/622.wav
#   inflating: wavs/6220.wav
#   inflating: wavs/6221.wav
#   inflating: wavs/6222.wav
#   inflating: wavs/6223.wav
#   inflating: wavs/6224.wav
#   inflating: wavs/6225.wav
#   inflating: wavs/6226.wav
#   inflating: wavs/6227.wav
#   inflating: wavs/6228.wav
#   inflating: wavs/6229.wav
#   inflating: wavs/623.wav
#   inflating: wavs/6230.wav
#   inflating: wavs/6231.wav
#   inflating: wavs/6232.wav
#   inflating: wavs/6233.wav
#   inflating: wavs/6234.wav
#   inflating: wavs/6235.wav
#   inflating: wavs/6236.wav
#   inflating: wavs/6237.wav
#   inflating: wavs/6238.wav
#   inflating: wavs/6239.wav
#   inflating: wavs/624.wav
#   inflating: wavs/6240.wav
#   inflating: wavs/6241.wav
#   inflating: wavs/6242.wav
#   inflating: wavs/6243.wav
#   inflating: wavs/6244.wav
#   inflating: wavs/6245.wav
#   inflating: wavs/6246.wav
#   inflating: wavs/6247.wav
#   inflating: wavs/6248.wav
#   inflating: wavs/6249.wav
#   inflating: wavs/625.wav
#   inflating: wavs/6250.wav
#   inflating: wavs/6251.wav
#   inflating: wavs/6252.wav
#   inflating: wavs/6253.wav
#   inflating: wavs/6254.wav
#   inflating: wavs/6255.wav
#   inflating: wavs/6256.wav
#   inflating: wavs/6257.wav
#   inflating: wavs/6258.wav
#   inflating: wavs/6259.wav
#   inflating: wavs/626.wav
#   inflating: wavs/6260.wav
#   inflating: wavs/6261.wav
#   inflating: wavs/6262.wav
#   inflating: wavs/6263.wav
#   inflating: wavs/6264.wav
#   inflating: wavs/6265.wav
#   inflating: wavs/6266.wav
#   inflating: wavs/6267.wav
#   inflating: wavs/6268.wav
#   inflating: wavs/6269.wav
#   inflating: wavs/627.wav
#   inflating: wavs/6270.wav
#   inflating: wavs/6271.wav
#   inflating: wavs/6272.wav
#   inflating: wavs/6273.wav
#   inflating: wavs/6274.wav
#   inflating: wavs/6275.wav
#   inflating: wavs/6276.wav
#   inflating: wavs/6277.wav
#   inflating: wavs/6278.wav
#   inflating: wavs/6279.wav
#   inflating: wavs/628.wav
#   inflating: wavs/6280.wav
#   inflating: wavs/6281.wav
#   inflating: wavs/6282.wav
#   inflating: wavs/6283.wav
#   inflating: wavs/6284.wav
#   inflating: wavs/6285.wav
#   inflating: wavs/6286.wav
#   inflating: wavs/6287.wav
#   inflating: wavs/6288.wav
#   inflating: wavs/6289.wav
#   inflating: wavs/629.wav
#   inflating: wavs/6290.wav
#   inflating: wavs/6291.wav
#   inflating: wavs/6292.wav
#   inflating: wavs/6293.wav
#   inflating: wavs/6294.wav
#   inflating: wavs/6295.wav
#   inflating: wavs/6296.wav
#   inflating: wavs/6297.wav
#   inflating: wavs/6298.wav
#   inflating: wavs/6299.wav
#   inflating: wavs/63.wav
#   inflating: wavs/630.wav
#   inflating: wavs/6300.wav
#   inflating: wavs/6301.wav
#   inflating: wavs/6302.wav
#   inflating: wavs/6303.wav
#   inflating: wavs/6304.wav
#   inflating: wavs/6305.wav
#   inflating: wavs/6306.wav
#   inflating: wavs/6307.wav
#   inflating: wavs/6308.wav
#   inflating: wavs/6309.wav
#   inflating: wavs/631.wav
#   inflating: wavs/6310.wav
#   inflating: wavs/6311.wav
#   inflating: wavs/6312.wav
#   inflating: wavs/6313.wav
#   inflating: wavs/6314.wav
#   inflating: wavs/6315.wav
#   inflating: wavs/6316.wav
#   inflating: wavs/6317.wav
#   inflating: wavs/6318.wav
#   inflating: wavs/6319.wav
#   inflating: wavs/632.wav
#   inflating: wavs/6320.wav
#   inflating: wavs/6321.wav
#   inflating: wavs/6322.wav
#   inflating: wavs/6323.wav
#   inflating: wavs/6324.wav
#   inflating: wavs/6325.wav
#   inflating: wavs/6326.wav
#   inflating: wavs/6327.wav
#   inflating: wavs/6328.wav
#   inflating: wavs/6329.wav
#   inflating: wavs/633.wav
#   inflating: wavs/6330.wav
#   inflating: wavs/6331.wav
#   inflating: wavs/6332.wav
#   inflating: wavs/6333.wav
#   inflating: wavs/6334.wav
#   inflating: wavs/6335.wav
#   inflating: wavs/6336.wav
#   inflating: wavs/6337.wav
#   inflating: wavs/6338.wav
#   inflating: wavs/6339.wav
#   inflating: wavs/634.wav
#   inflating: wavs/6340.wav
#   inflating: wavs/6341.wav
#   inflating: wavs/6342.wav
#   inflating: wavs/6343.wav
#   inflating: wavs/6344.wav
#   inflating: wavs/6345.wav
#   inflating: wavs/6346.wav
#   inflating: wavs/6347.wav
#   inflating: wavs/6348.wav
#   inflating: wavs/6349.wav
#   inflating: wavs/635.wav
#   inflating: wavs/6350.wav
#   inflating: wavs/6351.wav
#   inflating: wavs/6352.wav
#   inflating: wavs/6353.wav
#   inflating: wavs/6354.wav
#   inflating: wavs/6355.wav
#   inflating: wavs/6356.wav
#   inflating: wavs/6357.wav
#   inflating: wavs/6358.wav
#   inflating: wavs/6359.wav
#   inflating: wavs/636.wav
#   inflating: wavs/6360.wav
#   inflating: wavs/6361.wav
#   inflating: wavs/6362.wav
#   inflating: wavs/6363.wav
#   inflating: wavs/6364.wav
#   inflating: wavs/6365.wav
#   inflating: wavs/6366.wav
#   inflating: wavs/6367.wav
#   inflating: wavs/6368.wav
#   inflating: wavs/6369.wav
#   inflating: wavs/637.wav
#   inflating: wavs/6370.wav
#   inflating: wavs/6371.wav
#   inflating: wavs/6372.wav
#   inflating: wavs/6373.wav
#   inflating: wavs/6374.wav
#   inflating: wavs/6375.wav
#   inflating: wavs/6376.wav
#   inflating: wavs/6377.wav
#   inflating: wavs/6378.wav
#   inflating: wavs/6379.wav
#   inflating: wavs/638.wav
#   inflating: wavs/6380.wav
#   inflating: wavs/6381.wav
#   inflating: wavs/6382.wav
#   inflating: wavs/6383.wav
#   inflating: wavs/6384.wav
#   inflating: wavs/6385.wav
#   inflating: wavs/6386.wav
#   inflating: wavs/6387.wav
#   inflating: wavs/6388.wav
#   inflating: wavs/6389.wav
#   inflating: wavs/639.wav
#   inflating: wavs/6390.wav
#   inflating: wavs/6391.wav
#   inflating: wavs/6392.wav
#   inflating: wavs/6393.wav
#   inflating: wavs/6394.wav
#   inflating: wavs/6395.wav
#   inflating: wavs/6396.wav
#   inflating: wavs/6397.wav
#   inflating: wavs/6398.wav
#   inflating: wavs/6399.wav
#   inflating: wavs/64.wav
#   inflating: wavs/640.wav
#   inflating: wavs/6400.wav
#   inflating: wavs/6401.wav
#   inflating: wavs/6402.wav
#   inflating: wavs/6403.wav
#   inflating: wavs/6404.wav
#   inflating: wavs/6405.wav
#   inflating: wavs/6406.wav
#   inflating: wavs/6407.wav
#   inflating: wavs/6408.wav
#   inflating: wavs/6409.wav
#   inflating: wavs/641.wav
#   inflating: wavs/6410.wav
#   inflating: wavs/6411.wav
#   inflating: wavs/6412.wav
#   inflating: wavs/6413.wav
#   inflating: wavs/6414.wav
#   inflating: wavs/6415.wav
#   inflating: wavs/6416.wav
#   inflating: wavs/6417.wav
#   inflating: wavs/6418.wav
#   inflating: wavs/6419.wav
#   inflating: wavs/642.wav
#   inflating: wavs/6420.wav
#   inflating: wavs/6421.wav
#   inflating: wavs/6422.wav
#   inflating: wavs/6423.wav
#   inflating: wavs/6424.wav
#   inflating: wavs/6425.wav
#   inflating: wavs/6426.wav
#   inflating: wavs/6427.wav
#   inflating: wavs/6428.wav
#   inflating: wavs/6429.wav
#   inflating: wavs/643.wav
#   inflating: wavs/6430.wav
#   inflating: wavs/6431.wav
#   inflating: wavs/6432.wav
#   inflating: wavs/6433.wav
#   inflating: wavs/6434.wav
#   inflating: wavs/6435.wav
#   inflating: wavs/6436.wav
#   inflating: wavs/6437.wav
#   inflating: wavs/6438.wav
#   inflating: wavs/6439.wav
#   inflating: wavs/644.wav
#   inflating: wavs/6440.wav
#   inflating: wavs/6441.wav
#   inflating: wavs/6442.wav
#   inflating: wavs/6443.wav
#   inflating: wavs/6444.wav
#   inflating: wavs/6445.wav
#   inflating: wavs/6446.wav
#   inflating: wavs/6447.wav
#   inflating: wavs/6448.wav
#   inflating: wavs/6449.wav
#   inflating: wavs/645.wav
#   inflating: wavs/6450.wav
#   inflating: wavs/6451.wav
#   inflating: wavs/6452.wav
#   inflating: wavs/6453.wav
#   inflating: wavs/6454.wav
#   inflating: wavs/6455.wav
#   inflating: wavs/6456.wav
#   inflating: wavs/6457.wav
#   inflating: wavs/6458.wav
#   inflating: wavs/6459.wav
#   inflating: wavs/646.wav
#   inflating: wavs/6460.wav
#   inflating: wavs/6461.wav
#   inflating: wavs/6462.wav
#   inflating: wavs/6463.wav
#   inflating: wavs/6464.wav
#   inflating: wavs/6465.wav
#   inflating: wavs/6466.wav
#   inflating: wavs/6467.wav
#   inflating: wavs/6468.wav
#   inflating: wavs/6469.wav
#   inflating: wavs/647.wav
#   inflating: wavs/6470.wav
#   inflating: wavs/6471.wav
#   inflating: wavs/6472.wav
#   inflating: wavs/6473.wav
#   inflating: wavs/6474.wav
#   inflating: wavs/6475.wav
#   inflating: wavs/6476.wav
#   inflating: wavs/6477.wav
#   inflating: wavs/6478.wav
#   inflating: wavs/6479.wav
#   inflating: wavs/648.wav
#   inflating: wavs/6480.wav
#   inflating: wavs/6481.wav
#   inflating: wavs/6482.wav
#   inflating: wavs/6483.wav
#   inflating: wavs/6484.wav
#   inflating: wavs/6485.wav
#   inflating: wavs/6486.wav
#   inflating: wavs/6487.wav
#   inflating: wavs/6488.wav
#   inflating: wavs/6489.wav
#   inflating: wavs/649.wav
#   inflating: wavs/6490.wav
#   inflating: wavs/6491.wav
#   inflating: wavs/6492.wav
#   inflating: wavs/6493.wav
#   inflating: wavs/6494.wav
#   inflating: wavs/6495.wav
#   inflating: wavs/6496.wav
#   inflating: wavs/6497.wav
#   inflating: wavs/6498.wav
#   inflating: wavs/6499.wav
#   inflating: wavs/65.wav
#   inflating: wavs/650.wav
#   inflating: wavs/6500.wav
#   inflating: wavs/6501.wav
#   inflating: wavs/6502.wav
#   inflating: wavs/6503.wav
#   inflating: wavs/6504.wav
#   inflating: wavs/6505.wav
#   inflating: wavs/6506.wav
#   inflating: wavs/6507.wav
#   inflating: wavs/6508.wav
#   inflating: wavs/6509.wav
#   inflating: wavs/651.wav
#   inflating: wavs/6510.wav
#   inflating: wavs/6511.wav
#   inflating: wavs/6512.wav
#   inflating: wavs/6513.wav
#   inflating: wavs/6514.wav
#   inflating: wavs/6515.wav
#   inflating: wavs/6516.wav
#   inflating: wavs/6517.wav
#   inflating: wavs/6518.wav
#   inflating: wavs/6519.wav
#   inflating: wavs/652.wav
#   inflating: wavs/6520.wav
#   inflating: wavs/6521.wav
#   inflating: wavs/6522.wav
#   inflating: wavs/6523.wav
#   inflating: wavs/6524.wav
#   inflating: wavs/6525.wav
#   inflating: wavs/6526.wav
#   inflating: wavs/6527.wav
#   inflating: wavs/6528.wav
#   inflating: wavs/6529.wav
#   inflating: wavs/653.wav
#   inflating: wavs/6530.wav
#   inflating: wavs/6531.wav
#   inflating: wavs/6532.wav
#   inflating: wavs/6533.wav
#   inflating: wavs/6534.wav
#   inflating: wavs/6535.wav
#   inflating: wavs/6536.wav
#   inflating: wavs/6537.wav
#   inflating: wavs/6538.wav
#   inflating: wavs/6539.wav
#   inflating: wavs/654.wav
#   inflating: wavs/6540.wav
#   inflating: wavs/6541.wav
#   inflating: wavs/6542.wav
#   inflating: wavs/6543.wav
#   inflating: wavs/6544.wav
#   inflating: wavs/6545.wav
#   inflating: wavs/6546.wav
#   inflating: wavs/6547.wav
#   inflating: wavs/6548.wav
#   inflating: wavs/6549.wav
#   inflating: wavs/655.wav
#   inflating: wavs/6550.wav
#   inflating: wavs/6551.wav
#   inflating: wavs/6552.wav
#   inflating: wavs/6553.wav
#   inflating: wavs/6554.wav
#   inflating: wavs/6555.wav
#   inflating: wavs/6556.wav
#   inflating: wavs/6557.wav
#   inflating: wavs/6558.wav
#   inflating: wavs/6559.wav
#   inflating: wavs/656.wav
#   inflating: wavs/6560.wav
#   inflating: wavs/6561.wav
#   inflating: wavs/6562.wav
#   inflating: wavs/6563.wav
#   inflating: wavs/6564.wav
#   inflating: wavs/6565.wav
#   inflating: wavs/6566.wav
#   inflating: wavs/6567.wav
#   inflating: wavs/6568.wav
#   inflating: wavs/6569.wav
#   inflating: wavs/657.wav
#   inflating: wavs/6570.wav
#   inflating: wavs/6571.wav
#   inflating: wavs/6572.wav
#   inflating: wavs/6573.wav
#   inflating: wavs/6574.wav
#   inflating: wavs/6575.wav
#   inflating: wavs/6576.wav
#   inflating: wavs/6577.wav
#   inflating: wavs/6578.wav
#   inflating: wavs/6579.wav
#   inflating: wavs/658.wav
#   inflating: wavs/6580.wav
#   inflating: wavs/6581.wav
#   inflating: wavs/6582.wav
#   inflating: wavs/6583.wav
#   inflating: wavs/6584.wav
#   inflating: wavs/6585.wav
#   inflating: wavs/6586.wav
#   inflating: wavs/6587.wav
#   inflating: wavs/6588.wav
#   inflating: wavs/6589.wav
#   inflating: wavs/659.wav
#   inflating: wavs/6590.wav
#   inflating: wavs/6591.wav
#   inflating: wavs/6592.wav
#   inflating: wavs/6593.wav
#   inflating: wavs/6594.wav
#   inflating: wavs/6595.wav
#   inflating: wavs/6596.wav
#   inflating: wavs/6597.wav
#   inflating: wavs/6598.wav
#   inflating: wavs/6599.wav
#   inflating: wavs/66.wav
#   inflating: wavs/660.wav
#   inflating: wavs/6600.wav
#   inflating: wavs/6601.wav
#   inflating: wavs/6602.wav
#   inflating: wavs/6603.wav
#   inflating: wavs/6604.wav
#   inflating: wavs/6605.wav
#   inflating: wavs/6606.wav
#   inflating: wavs/6607.wav
#   inflating: wavs/6608.wav
#   inflating: wavs/6609.wav
#   inflating: wavs/661.wav
#   inflating: wavs/6610.wav
#   inflating: wavs/6611.wav
#   inflating: wavs/6612.wav
#   inflating: wavs/6613.wav
#   inflating: wavs/6614.wav
#   inflating: wavs/6615.wav
#   inflating: wavs/6616.wav
#   inflating: wavs/6617.wav
#   inflating: wavs/6618.wav
#   inflating: wavs/6619.wav
#   inflating: wavs/662.wav
#   inflating: wavs/6620.wav
#   inflating: wavs/6621.wav
#   inflating: wavs/6622.wav
#   inflating: wavs/6623.wav
#   inflating: wavs/6624.wav
#   inflating: wavs/6625.wav
#   inflating: wavs/6626.wav
#   inflating: wavs/6627.wav
#   inflating: wavs/6628.wav
#   inflating: wavs/6629.wav
#   inflating: wavs/663.wav
#   inflating: wavs/6630.wav
#   inflating: wavs/6631.wav
#   inflating: wavs/6632.wav
#   inflating: wavs/6633.wav
# ...
#   inflating: wavs/962.wav
#   inflating: wavs/9620.wav
#   inflating: wavs/9621.wav
#   inflating: wavs/9622.wav
#   inflating: wavs/9623.wav
#   inflating: wavs/9624.wav
#   inflating: wavs/9625.wav
#   inflating: wavs/9626.wav
#   inflating: wavs/9627.wav
#   inflating: wavs/9628.wav
#   inflating: wavs/9629.wav
#   inflating: wavs/963.wav
#   inflating: wavs/9630.wav
#   inflating: wavs/9631.wav
#   inflating: wavs/9632.wav
#   inflating: wavs/9633.wav
#   inflating: wavs/9634.wav
#   inflating: wavs/9635.wav
#   inflating: wavs/9636.wav
#   inflating: wavs/9637.wav
#   inflating: wavs/9638.wav
#   inflating: wavs/9639.wav
#   inflating: wavs/964.wav
#   inflating: wavs/9640.wav
#   inflating: wavs/9641.wav
#   inflating: wavs/9642.wav
#   inflating: wavs/9643.wav
#   inflating: wavs/9644.wav
#   inflating: wavs/9645.wav
#   inflating: wavs/9646.wav
#   inflating: wavs/9647.wav
#   inflating: wavs/9648.wav
#   inflating: wavs/9649.wav
#   inflating: wavs/965.wav
#   inflating: wavs/9650.wav
#   inflating: wavs/9651.wav
#   inflating: wavs/9652.wav
#   inflating: wavs/9653.wav
#   inflating: wavs/9654.wav
#   inflating: wavs/9655.wav
#   inflating: wavs/9656.wav
#   inflating: wavs/9657.wav
#   inflating: wavs/9658.wav
#   inflating: wavs/9659.wav
#   inflating: wavs/966.wav
#   inflating: wavs/9660.wav
#   inflating: wavs/9661.wav
#   inflating: wavs/9662.wav
#   inflating: wavs/9663.wav
#   inflating: wavs/9664.wav
#   inflating: wavs/9665.wav
#   inflating: wavs/9666.wav
#   inflating: wavs/9667.wav
#   inflating: wavs/9668.wav
#   inflating: wavs/9669.wav
#   inflating: wavs/967.wav
#   inflating: wavs/9670.wav
#   inflating: wavs/9671.wav
#   inflating: wavs/9672.wav
#   inflating: wavs/9673.wav
#   inflating: wavs/9674.wav
#   inflating: wavs/9675.wav
#   inflating: wavs/9676.wav
#   inflating: wavs/9677.wav
#   inflating: wavs/9678.wav
#   inflating: wavs/9679.wav
#   inflating: wavs/968.wav
#   inflating: wavs/9680.wav
#   inflating: wavs/9681.wav
#   inflating: wavs/9682.wav
#   inflating: wavs/9683.wav
#   inflating: wavs/9684.wav
#   inflating: wavs/9685.wav
#   inflating: wavs/9686.wav
#   inflating: wavs/9687.wav
#   inflating: wavs/9688.wav
#   inflating: wavs/9689.wav
#   inflating: wavs/969.wav
#   inflating: wavs/9690.wav
#   inflating: wavs/9691.wav
#   inflating: wavs/9692.wav
#   inflating: wavs/9693.wav
#   inflating: wavs/9694.wav
#   inflating: wavs/9695.wav
#   inflating: wavs/9696.wav
#   inflating: wavs/9697.wav
#   inflating: wavs/9698.wav
#   inflating: wavs/9699.wav
#   inflating: wavs/97.wav
#   inflating: wavs/970.wav
#   inflating: wavs/9700.wav
#   inflating: wavs/9701.wav
#   inflating: wavs/9702.wav
#   inflating: wavs/9703.wav
#   inflating: wavs/9704.wav
#   inflating: wavs/9705.wav
#   inflating: wavs/9706.wav
#   inflating: wavs/9707.wav
#   inflating: wavs/9708.wav
#   inflating: wavs/9709.wav
#   inflating: wavs/971.wav
#   inflating: wavs/9710.wav
#   inflating: wavs/9711.wav
#   inflating: wavs/9712.wav
#   inflating: wavs/9713.wav
#   inflating: wavs/9714.wav
#   inflating: wavs/9715.wav
#   inflating: wavs/9716.wav
#   inflating: wavs/9717.wav
#   inflating: wavs/9718.wav
#   inflating: wavs/9719.wav
#   inflating: wavs/972.wav
#   inflating: wavs/9720.wav
#   inflating: wavs/9721.wav
#   inflating: wavs/9722.wav
#   inflating: wavs/9723.wav
#   inflating: wavs/9724.wav
#   inflating: wavs/9725.wav
#   inflating: wavs/9726.wav
#   inflating: wavs/9727.wav
#   inflating: wavs/9728.wav
#   inflating: wavs/9729.wav
#   inflating: wavs/973.wav
#   inflating: wavs/9730.wav
#   inflating: wavs/9731.wav
#   inflating: wavs/9732.wav
#   inflating: wavs/9733.wav
#   inflating: wavs/9734.wav
#   inflating: wavs/9735.wav
#   inflating: wavs/9736.wav
#   inflating: wavs/9737.wav
#   inflating: wavs/9738.wav
#   inflating: wavs/9739.wav
#   inflating: wavs/974.wav
#   inflating: wavs/9740.wav
#   inflating: wavs/9741.wav
#   inflating: wavs/9742.wav
#   inflating: wavs/9743.wav
#   inflating: wavs/9744.wav
#   inflating: wavs/9745.wav
#   inflating: wavs/9746.wav
#   inflating: wavs/9747.wav
#   inflating: wavs/9748.wav
#   inflating: wavs/9749.wav
#   inflating: wavs/975.wav
#   inflating: wavs/9750.wav
#   inflating: wavs/9751.wav
#   inflating: wavs/9752.wav
#   inflating: wavs/9753.wav
#   inflating: wavs/9754.wav
#   inflating: wavs/9755.wav
#   inflating: wavs/9756.wav
#   inflating: wavs/9757.wav
#   inflating: wavs/9758.wav
#   inflating: wavs/9759.wav
#   inflating: wavs/976.wav
#   inflating: wavs/9760.wav
#   inflating: wavs/9761.wav
#   inflating: wavs/9762.wav
#   inflating: wavs/9763.wav
#   inflating: wavs/9764.wav
#   inflating: wavs/9765.wav
#   inflating: wavs/9766.wav
#   inflating: wavs/9767.wav
#   inflating: wavs/9768.wav
#   inflating: wavs/9769.wav
#   inflating: wavs/977.wav
#   inflating: wavs/9770.wav
#   inflating: wavs/9771.wav
#   inflating: wavs/9772.wav
#   inflating: wavs/9773.wav
#   inflating: wavs/9774.wav
#   inflating: wavs/9775.wav
#   inflating: wavs/9776.wav
#   inflating: wavs/9777.wav
#   inflating: wavs/9778.wav
#   inflating: wavs/9779.wav
#   inflating: wavs/978.wav
#   inflating: wavs/9780.wav
#   inflating: wavs/9781.wav
#   inflating: wavs/9782.wav
#   inflating: wavs/9783.wav
#   inflating: wavs/9784.wav
#   inflating: wavs/9785.wav
#   inflating: wavs/9786.wav
#   inflating: wavs/9787.wav
#   inflating: wavs/9788.wav
#   inflating: wavs/9789.wav
#   inflating: wavs/979.wav
#   inflating: wavs/9790.wav
#   inflating: wavs/9791.wav
#   inflating: wavs/9792.wav
#   inflating: wavs/9793.wav
#   inflating: wavs/9794.wav
#   inflating: wavs/9795.wav
#   inflating: wavs/9796.wav
#   inflating: wavs/9797.wav
#   inflating: wavs/9798.wav
#   inflating: wavs/9799.wav
#   inflating: wavs/98.wav
#   inflating: wavs/980.wav
#   inflating: wavs/9800.wav
#   inflating: wavs/9801.wav
#   inflating: wavs/9802.wav
#   inflating: wavs/9803.wav
#   inflating: wavs/9804.wav
#   inflating: wavs/9805.wav
#   inflating: wavs/9806.wav
#   inflating: wavs/9807.wav
#   inflating: wavs/9808.wav
#   inflating: wavs/9809.wav
#   inflating: wavs/981.wav
#   inflating: wavs/9810.wav
#   inflating: wavs/9811.wav
#   inflating: wavs/9812.wav
#   inflating: wavs/9813.wav
#   inflating: wavs/9814.wav
#   inflating: wavs/9815.wav
#   inflating: wavs/9816.wav
#   inflating: wavs/9817.wav
#   inflating: wavs/9818.wav
#   inflating: wavs/9819.wav
#   inflating: wavs/982.wav
#   inflating: wavs/9820.wav
#   inflating: wavs/9821.wav
#   inflating: wavs/9822.wav
#   inflating: wavs/9823.wav
#   inflating: wavs/9824.wav
#   inflating: wavs/9825.wav
#   inflating: wavs/9826.wav
#   inflating: wavs/9827.wav
#   inflating: wavs/9828.wav
#   inflating: wavs/9829.wav
#   inflating: wavs/983.wav
#   inflating: wavs/9830.wav
#   inflating: wavs/9831.wav
#   inflating: wavs/9832.wav
#   inflating: wavs/9833.wav
#   inflating: wavs/9834.wav
#   inflating: wavs/9835.wav
#   inflating: wavs/9836.wav
#   inflating: wavs/9837.wav
#   inflating: wavs/9838.wav
#   inflating: wavs/9839.wav
#   inflating: wavs/984.wav
#   inflating: wavs/9840.wav
#   inflating: wavs/9841.wav
#   inflating: wavs/9842.wav
#   inflating: wavs/9843.wav
#   inflating: wavs/9844.wav
#   inflating: wavs/9845.wav
#   inflating: wavs/9846.wav
#   inflating: wavs/9847.wav
#   inflating: wavs/9848.wav
#   inflating: wavs/9849.wav
#   inflating: wavs/985.wav
#   inflating: wavs/9850.wav
#   inflating: wavs/9851.wav
#   inflating: wavs/9852.wav
#   inflating: wavs/9853.wav
#   inflating: wavs/9854.wav
#   inflating: wavs/9855.wav
#   inflating: wavs/9856.wav
#   inflating: wavs/9857.wav
#   inflating: wavs/9858.wav
#   inflating: wavs/9859.wav
#   inflating: wavs/986.wav
#   inflating: wavs/9860.wav
#   inflating: wavs/9861.wav
#   inflating: wavs/9862.wav
#   inflating: wavs/9863.wav
#   inflating: wavs/9864.wav
#   inflating: wavs/9865.wav
#   inflating: wavs/9866.wav
#   inflating: wavs/9867.wav
#   inflating: wavs/9868.wav
#   inflating: wavs/9869.wav
#   inflating: wavs/987.wav
#   inflating: wavs/9870.wav
#   inflating: wavs/9871.wav
#   inflating: wavs/9872.wav
#   inflating: wavs/9873.wav
#   inflating: wavs/9874.wav
#   inflating: wavs/9875.wav
#   inflating: wavs/9876.wav
#   inflating: wavs/9877.wav
#   inflating: wavs/9878.wav
#   inflating: wavs/9879.wav
#   inflating: wavs/988.wav
#   inflating: wavs/9880.wav
#   inflating: wavs/9881.wav
#   inflating: wavs/9882.wav
#   inflating: wavs/9883.wav
#   inflating: wavs/9884.wav
#   inflating: wavs/9885.wav
#   inflating: wavs/9886.wav
#   inflating: wavs/9887.wav
#   inflating: wavs/9888.wav
#   inflating: wavs/9889.wav
#   inflating: wavs/989.wav
#   inflating: wavs/9890.wav
#   inflating: wavs/9891.wav
#   inflating: wavs/9892.wav
#   inflating: wavs/9893.wav
#   inflating: wavs/9894.wav
#   inflating: wavs/9895.wav
#   inflating: wavs/9896.wav
#   inflating: wavs/9897.wav
#   inflating: wavs/9898.wav
#   inflating: wavs/9899.wav
#   inflating: wavs/99.wav
#   inflating: wavs/990.wav
#   inflating: wavs/9900.wav
#   inflating: wavs/9901.wav
#   inflating: wavs/9902.wav
#   inflating: wavs/9903.wav
#   inflating: wavs/9904.wav
#   inflating: wavs/9905.wav
#   inflating: wavs/9906.wav
#   inflating: wavs/9907.wav
#   inflating: wavs/9908.wav
#   inflating: wavs/9909.wav
#   inflating: wavs/991.wav
#   inflating: wavs/9910.wav
#   inflating: wavs/9911.wav
#   inflating: wavs/9912.wav
#   inflating: wavs/9913.wav
#   inflating: wavs/9914.wav
#   inflating: wavs/9915.wav
#   inflating: wavs/9916.wav
#   inflating: wavs/9917.wav
#   inflating: wavs/9918.wav
#   inflating: wavs/9919.wav
#   inflating: wavs/992.wav
#   inflating: wavs/9920.wav
#   inflating: wavs/9921.wav
#   inflating: wavs/9922.wav
#   inflating: wavs/9923.wav
#   inflating: wavs/9924.wav
#   inflating: wavs/9925.wav
#   inflating: wavs/9926.wav
#   inflating: wavs/9927.wav
#   inflating: wavs/9928.wav
#   inflating: wavs/9929.wav
#   inflating: wavs/993.wav
#   inflating: wavs/9930.wav
#   inflating: wavs/9931.wav
#   inflating: wavs/9932.wav
#   inflating: wavs/9933.wav
#   inflating: wavs/9934.wav
#   inflating: wavs/9935.wav
#   inflating: wavs/9936.wav
#   inflating: wavs/9937.wav
#   inflating: wavs/9938.wav
#   inflating: wavs/9939.wav
#   inflating: wavs/994.wav
#   inflating: wavs/9940.wav
#   inflating: wavs/9941.wav
#   inflating: wavs/9942.wav
#   inflating: wavs/9943.wav
#   inflating: wavs/9944.wav
#   inflating: wavs/9945.wav
#   inflating: wavs/9946.wav
#   inflating: wavs/9947.wav
#   inflating: wavs/9948.wav
#   inflating: wavs/9949.wav
#   inflating: wavs/995.wav
#   inflating: wavs/9950.wav
#   inflating: wavs/9951.wav
#   inflating: wavs/9952.wav
#   inflating: wavs/9953.wav
#   inflating: wavs/9954.wav
#   inflating: wavs/9955.wav
#   inflating: wavs/9956.wav
#   inflating: wavs/9957.wav
#   inflating: wavs/9958.wav
#   inflating: wavs/9959.wav
#   inflating: wavs/996.wav
#   inflating: wavs/9960.wav
#   inflating: wavs/9961.wav
#   inflating: wavs/9962.wav
#   inflating: wavs/9963.wav
#   inflating: wavs/9964.wav
#   inflating: wavs/9965.wav
#   inflating: wavs/9966.wav
#   inflating: wavs/9967.wav
#   inflating: wavs/9968.wav
#   inflating: wavs/9969.wav
#   inflating: wavs/997.wav
#   inflating: wavs/9970.wav
#   inflating: wavs/9971.wav
#   inflating: wavs/9972.wav
#   inflating: wavs/9973.wav
#   inflating: wavs/9974.wav
#   inflating: wavs/9975.wav
#   inflating: wavs/9976.wav
#   inflating: wavs/9977.wav
#   inflating: wavs/9978.wav
#   inflating: wavs/9979.wav
#   inflating: wavs/998.wav
#   inflating: wavs/9980.wav
#   inflating: wavs/9981.wav
#   inflating: wavs/9982.wav
#   inflating: wavs/9983.wav
#   inflating: wavs/9984.wav
#   inflating: wavs/9985.wav
#   inflating: wavs/9986.wav
#   inflating: wavs/9987.wav
#   inflating: wavs/9988.wav
#   inflating: wavs/9989.wav
#   inflating: wavs/999.wav
#   inflating: wavs/9990.wav
#   inflating: wavs/9991.wav
#   inflating: wavs/9992.wav
#   inflating: wavs/9993.wav
#   inflating: wavs/9994.wav
#   inflating: wavs/9995.wav
#   inflating: wavs/9996.wav
#   inflating: wavs/9997.wav
#   inflating: wavs/9998.wav
#   inflating: wavs/9999.wav

# %%
# 5. Paths
drive_path = "/content/drive/MyDrive/colab"
dataset_path = "/content/TTS-TT2/wavs"
transcript_file = "/content/TTS-TT2/filelists/test.txt"

# %%
outdir = f"{drive_path}/outdir"
logdir = f"{drive_path}/logs"

# %%
os.makedirs(outdir, exist_ok=True)
os.makedirs(logdir, exist_ok=True)

# %%
# 7. Hyperparameters
hparams = create_hparams()
hparams.batch_size = 32
hparams.epochs = 250
hparams.learning_rate = 1e-3
hparams.max_decoder_steps = 1000
hparams.n_mel_channels = 80

# %%
train_filelist = transcript_file
val_filelist = transcript_file

# %%
train(
    output_directory=outdir,
    log_directory=logdir,
    checkpoint_path=None,       # or a checkpoint to resume
    warm_start=True,
    n_gpus=1,
    rank=0,
    group_name='tacotron2_group',
    hparams=hparams,
    training_files=train_filelist,
    validation_files=val_filelist,
    epochs=hparams.epochs
)

# %%
#@markdown ## <font color="pink"> **3. Load dataset.** 📥
#@markdown ---
#@markdown #### The audios can be compressed in a **ZIP** file (recommended) or loose.
#@markdown #### You can also manually upload the ZIP/folder and enter the path in the field below, or import your audios from Drive by entering the path in the template "/content/drive/My Drive/your_file". If you want to **upload in the cell itself, leave the field empty**.
#@markdown ---
#@markdown #### Enable audio processing?
#@markdown Remember that they must be in a compatible format, i.e., sample rate <font color="orange">**22050, 16 bit, mono**</font>. If you do not have the audios in this format, check this box to make the conversion, apart from normalization and silence removal.
audio_processing = True #@param {type:"boolean"}
drive_path = "/content/drive/MyDrive/dataset.zip" #@param {type: "string"}

from google.colab import files
import zipfile
import os
import wave
import shutil
import datetime

if os.listdir('/content/TTS-TT2/wavs/'):
  # !rm /content/TTS-TT2/wavs/*

with open('/content/audios.sh', 'w') as rsh:
    rsh.write('''\
for file in /content/TTS-TT2/wavs/*.wav
do
    ffmpeg -y -i "$file" -ar 22050 /content/tempwav/srtmp.wav -loglevel error
    ffmpeg -y -i /content/tempwav/srtmp.wav -c copy -fflags +bitexact -flags:v +bitexact -flags:a +bitexact -ar 22050 /content/tempwav/poop.wav -loglevel error
    rm "$file"
    mv /content/tempwav/poop.wav "$file"
    rm /content/tempwav/*
done
''')

# %cd /content/TTS-TT2/wavs

drive_path = drive_path.strip()

if drive_path:
  if os.path.exists(drive_path):
    print(f"\n\033[34m\033[1mAudio imported from Drive.\n\033[90m")
    if zipfile.is_zipfile(drive_path):
      # !unzip -q -j "$drive_path" -d /content/TTS-TT2/wavs

    else:
      fp = drive_path + "/."
      # !cp -a "$fp" "/content/TTS-TT2/wavs"
  else:
    print(f"\n\033[33m\033[1m[NOTICE] The path {drive_path} is not found, check for errors and try again.")
    print(f"\n\033[34m\033[1mUpload your dataset(audios)...")
    uploaded = files.upload()
else:
  print(f"\n\033[34m\033[1mUpload your dataset(audios)...")
  uploaded = files.upload()

  for fn in uploaded.keys():
    if zipfile.is_zipfile(fn):
      # !unzip -q -j "$fn" -d /content/TTS-TT2/wavs
      # !rm "$fn"

if os.path.exists("/content/TTS-TT2/wavs/wavs"):
    for file in os.listdir("/content/TTS-TT2/wavs/wavs"):
      # !mv /content/TTS-TT2/wavs/wavs/"$file"  /content/TTS-TT2/wavs/"$file"
# !rm /content/TTS-TT2/wavs/list.txt
if audio_processing:
  print(f"\n\033[37mMetadata removal and audio verification...")
  # !mkdir /content/tempwav
  # !bash /content/audios.sh

totalduration = 0
for file_name in [x for x in os.listdir() if os.path.isfile(x)]:
    with wave.open(file_name, "rb") as wave_file:
        frames = wave_file.getnframes()
        rate = wave_file.getframerate()
        duration = frames / float(rate)
        totalduration += duration

        if duration >= 12:
          print(f"\n\033[33m\033[1m[NOTICE] {file_name} is longer than 12 seconds. Lack of RAM can"
                " occur in a large batch size!")

wav_count = len(os.listdir("/content/TTS-TT2/wavs"))
print(f"\n{wav_count} processed audios. total duration: {str(datetime.timedelta(seconds=round(totalduration, 0)))}\n")

#shutil.make_archive("/content/processedwavs", 'zip', '/content/TTS-TT2/wavs')
#files.download('/content/processedwavs.zip')

print("\n\033[32m\033[1mAll set, please proceed.")

# %%
#@markdown ## <font color="pink"> **4. Upload the transcript.** 📝
#@markdown The transcript must be a ``.TXT`` file formatted in <font color="red" size="+3"> ``UTF-8 without BOM.``

from google.colab import files
import os

# %cd /content/TTS-TT2/filelists/
# !rm /content/TTS-TT2/filelists/list.txt

print("\n\033[34m\033[1mUpload your transcript(list)...")
listfn, length = files.upload().popitem()

if listfn != "list.txt":
  # !mv "$listfn" list.txt


with open('list.txt', 'r') as f:
    lines = f.readlines()


new_lines = []
for line in lines:
    audio_file_path = '/content/TTS-TT2/' + line.split('|')[0]

    if os.path.exists(audio_file_path):
        new_lines.append(line)


with open('list.txt', 'w') as f:
    f.writelines(new_lines)

# %cd /content/TTS-TT2/
print("\n\033[32m\033[1mAll set, please proceed.")

# %%
#@markdown ## <font color="pink"> **5. Configure the model parameters.** 🎛️

#@markdown ---

#@markdown #### Your desired model name:

model_filename = 'test' #@param {type: "string"}

#@markdown #### Upload your transcription / text to TTS-TT2/filelists and right click -> copy path:
Training_file = "filelists/list.txt" #@param {type: "string"}
hparams.training_files = Training_file
hparams.validation_files = Training_file




# hparams to Tune
#hparams.use_mmi=True,          # not used in this notebook
#hparams.use_gaf=True,          # not used in this notebook
#hparams.max_gaf=0.5,           # not used in this notebook
#hparams.drop_frame_rate = 0.2  # not used in this notebook
hparams.p_attention_dropout=0.1
hparams.p_decoder_dropout=0.1

# Learning Rate             # https://www.desmos.com/calculator/ptgcz4vzsw / http://boards.4channel.org/mlp/thread/34778298#p34789030
hparams.decay_start = 15000         # wait till decay_start to start decaying learning rate

#@markdown #### Lower learning rates will take more time but will lead to more accurate results:
# Start/Max Learning Rate
hparams.A_ = 3e-4 #@param ["3e-6", "1e-5", "1e-4", "5e-4", "1e-3"] {type:"raw", allow-input: true}
hparams.B_ = 8000                   # Decay Rate
hparams.C_ = 0                      # Shift learning rate equation by this value
hparams.min_learning_rate = 1e-5    # Min Learning Rate

# Quality of Life
generate_mels = True
hparams.show_alignments = True
alignment_graph_height = 600
alignment_graph_width = 1000

#@markdown #### Your batch size, lower if you don't have enough ram:

hparams.batch_size =  8#@param {type: "integer"}
hparams.load_mel_from_disk = True
hparams.ignore_layers = [] # Layers to reset (None by default, other than foreign languages this param can be ignored)
use_cmudict = True #@param {type:"boolean"}
#@markdown #### Your total epochs to train to. Not recommended to change:

##@markdown #### Amount of epochs before stopping, preferably a very high amount to not stop.
hparams.epochs =  250#@param {type: "integer"}

torch.backends.cudnn.enabled = hparams.cudnn_enabled
torch.backends.cudnn.benchmark = hparams.cudnn_benchmark

#@markdown #### Where to save your model when training:
output_directory = '/content/drive/MyDrive/colab/outdir' #@param {type: "string"}
log_directory = '/content/TTS-TT2/logs' # Location to save Log files locally
log_directory2 = '/content/drive/My Drive/colab/logs' # Location to copy log files (done at the end of each epoch to cut down on I/O)
checkpoint_path = output_directory+(r'/')+model_filename

##@markdown #### Train the model from scratch? (If yes, then uncheck the box below):
#warm_start=True #@param {type:"boolean"}


#@markdown ---
hparams.text_cleaners=["english_cleaners"] + (["cmudict_cleaners"] if use_cmudict is True else [])


#@markdown Note:-

#@markdown - The learning_rate value is ordered from smallest to largest, top to bottom.

#@markdown - The smaller the "learning rates" value is, the longer it will take to train the model, but the more accurate the results will be.

#@markdown ___

#@markdown Todo:-
#@markdown - Disable warm_start
#@markdown - Add tensorboard training monitor

#@markdown ___

# %%
#@markdown ## <font color="pink"> **6. Convert the .WAV files to Mel spectrograms and check the files.** 🔉>📈

if generate_mels:
    create_mels()

print("Checking for missing files")
# ---- Replace .wav with .npy in filelists ----
# !sed -i -- 's,.wav|,.npy|,g' {hparams.training_files}; sed -i -- 's,.wav|,.npy|,g' {hparams.validation_files}

check_dataset(hparams)

# %%
#@markdown ## <b><font color="pink"> **7. Check the working cmudict patch** 🩹
# %cd /content/TTS-TT2/
import text
print(text.sequence_to_text(text.text_to_sequence("We must capture an Earth creature, K 9, and return it back with us to Mars.", ["cmudict_cleaners", "english_cleaners"])))

# %%
#@markdown # <font color="pink"> **8. Begin training.** 🏋️
#@markdown ___
#@markdown ### How often to save (number of epochs)
#@markdown `10` by default. Raise this if you're hitting a rate limit. If you're using a particularly large dataset, you might want to set this to `1` to prevent loss of progress.
save_interval =  10#@param {type: "integer"}
#
#@markdown ### How often to backup (number of epochs)
#@markdown `-1` (disabled) by default. This will save extra copies of your model every so often, so you always have something to revert to if you train the model for too long. This *will* chew through your Google Drive storage.
backup_interval =  -1#@param {type: "integer"}
#

print('FP16 Run:', hparams.fp16_run)
print('Dynamic Loss Scaling:', hparams.dynamic_loss_scaling)
print('Distributed Run:', hparams.distributed_run)
print('cuDNN Enabled:', hparams.cudnn_enabled)
print('cuDNN Benchmark:', hparams.cudnn_benchmark)
train(output_directory, log_directory, checkpoint_path,
      warm_start, n_gpus, rank, group_name, hparams, log_directory2,
      save_interval, backup_interval)

# %% [markdown]
# # **Final notes**
#
# ## A good training looks like this:
# ![img.png](https://media.discordapp.net/attachments/835971020569051216/851469553355587614/download_2.png)
